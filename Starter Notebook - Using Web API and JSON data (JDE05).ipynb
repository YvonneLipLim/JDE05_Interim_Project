# %% [markdown]
# # From Web API in JSON Format to Pandas with Python

# %% [markdown]
# Credits and References:
# - By: Justin Chae | @justinhchae | https://medium.com/@jhc154 | https://www.linkedin.com/in/justin-chae
# - https://colab.research.google.com/drive/1yD3aOCI4XFrfpBqNXlxStU5veRPHvaL0?usp=sharing
# - https://plainenglish.io/blog/from-api-to-pandas-getting-json-data-with-python-df127f699b6b

# %% [markdown]
# - https://medium.com/swlh/handle-json-data-using-json-and-pandas-in-python-9ff6bbd0d356
# - https://opendata.dc.gov/
# (Go to API explorer of the chosen dataset and select the Query URL)

# %% [markdown]
# - https://medium.com/@technige/what-does-requests-offer-over-urllib3-in-2022-e6a38d9273d9
# - https://www.zenrows.com/blog/urllib3-vs-requests#feature-comparison

# %% [markdown]
# An example of getting JSON data from an Open Data site with Python into a Pandas Dataframe.

# %% [markdown]
# # **Step 0 - Import and Install Libraries**

# %%
#do this if needed.
# !pip install certifi

# %%
# urllib3 is a powerful, user-friendly HTTP client for Python
# to handle  data retrieval
import urllib3
from urllib3 import request

# to handle certificate verification
import certifi

# to manage json data
import json

# for pandas dataframes
import pandas as pd

# %% [markdown]
# # **Step 1 - Set Up Handler for Certificates and SSL Warnings**

# %%
# handle certificate verification and SSL warnings:
# reference https://urllib3.readthedocs.io/en/latest/user-guide.html#ssl

http = urllib3.PoolManager(
    cert_reqs='CERT_REQUIRED',
    ca_certs=certifi.where())

# Creating a PoolManager instance for sending requests with outout any verification or warning handlings
#http = urllib3.PoolManager()

# %%
type(http)
# Out:
# urllib3.poolmanager.PoolManager

# %% [markdown]
# # **Step 2 - Get Data from Web API with Requests**

# %%
# get data from the API; replace url with target source
url = 'https://maps2.dcgis.dc.gov/dcgis/rest/services/FEEDS/MPD/MapServer/2/query?where=1%3D1&outFields=*&outSR=4326&f=json'
#url ='https://maps2.dcgis.dc.gov/dcgis/rest/services/DCGIS_DATA/Education_WebMercator/MapServer/5/query?where=1%3D1&outFields=*&outSR=4326&f=json'

r = http.request('GET', url)
r.status
# Out:
# 200

# %% [markdown]
# # **Step 3 - Decode JSON Data to a Dict**

# %%
type(r.data.decode('utf-8'))
# Out:
# str

# %%
# decode json data/string into a Python dict object
data = json.loads(r.data.decode('utf-8'))

type(data)
# Out:
# dict

# %%
data
# Out:
# {'displayFieldName': 'CCN',
#  'fieldAliases': {'CCN': 'CCN',
#   'REPORT_DAT': 'REPORT_DATE',
#   'SHIFT': 'SHIFT',
#   'METHOD': 'METHOD',
#   'OFFENSE': 'OFFENSE',
#   'BLOCK': 'BLOCK',
#   'XBLOCK': 'XBLOCK',
#   'YBLOCK': 'YBLOCK',
#   'WARD': 'WARD',
#   'ANC': 'ANC',
#   'DISTRICT': 'DISTRICT',
#   'PSA': 'PSA',
#   'NEIGHBORHOOD_CLUSTER': 'NEIGHBORHOOD_CLUSTER',
#   'BLOCK_GROUP': 'BLOCK_GROUP',
#   'CENSUS_TRACT': 'CENSUS_TRACT',
#   'VOTING_PRECINCT': 'VOTING_PRECINCT',
#   'LATITUDE': 'LATITUDE',
#   'LONGITUDE': 'LONGITUDE',
#   'BID': 'BID',
#   'START_DATE': 'START_DATE',
#   'END_DATE': 'END_DATE',
#   'OBJECTID': 'OBJECTID',
#   'OCTO_RECORD_ID': 'OCTO_RECORD_ID'},
#  'geometryType': 'esriGeometryPoint',
#  'spatialReference': {'wkid': 4326, 'latestWkid': 4326},
#  'fields': [{'name': 'CCN',
#    'type': 'esriFieldTypeString',
#    'alias': 'CCN',
#    'length': 8},
#   {'name': 'REPORT_DAT',
#    'type': 'esriFieldTypeDate',
#    'alias': 'REPORT_DATE',
#    'length': 8},
#   {'name': 'SHIFT',
#    'type': 'esriFieldTypeString',
#    'alias': 'SHIFT',
#    'length': 50},
#   {'name': 'METHOD',
#    'type': 'esriFieldTypeString',
#    'alias': 'METHOD',
#    'length': 50},
#   {'name': 'OFFENSE',
#    'type': 'esriFieldTypeString',
#    'alias': 'OFFENSE',
#    'length': 250},
#   {'name': 'BLOCK',
#    'type': 'esriFieldTypeString',
#    'alias': 'BLOCK',
#    'length': 100},
#   {'name': 'XBLOCK', 'type': 'esriFieldTypeDouble', 'alias': 'XBLOCK'},
#   {'name': 'YBLOCK', 'type': 'esriFieldTypeDouble', 'alias': 'YBLOCK'},
#   {'name': 'WARD',
#    'type': 'esriFieldTypeString',
#    'alias': 'WARD',
#    'length': 1},
#   {'name': 'ANC', 'type': 'esriFieldTypeString', 'alias': 'ANC', 'length': 5},
#   {'name': 'DISTRICT',
#    'type': 'esriFieldTypeString',
#    'alias': 'DISTRICT',
#    'length': 1},
#   {'name': 'PSA', 'type': 'esriFieldTypeString', 'alias': 'PSA', 'length': 3},
#   {'name': 'NEIGHBORHOOD_CLUSTER',
#    'type': 'esriFieldTypeString',
#    'alias': 'NEIGHBORHOOD_CLUSTER',
#    'length': 200},
#   {'name': 'BLOCK_GROUP',
#    'type': 'esriFieldTypeString',
#    'alias': 'BLOCK_GROUP',
#    'length': 20},
#   {'name': 'CENSUS_TRACT',
#    'type': 'esriFieldTypeString',
#    'alias': 'CENSUS_TRACT',
#    'length': 20},
#   {'name': 'VOTING_PRECINCT',
#    'type': 'esriFieldTypeString',
#    'alias': 'VOTING_PRECINCT',
#    'length': 25},
#   {'name': 'LATITUDE', 'type': 'esriFieldTypeDouble', 'alias': 'LATITUDE'},
#   {'name': 'LONGITUDE', 'type': 'esriFieldTypeDouble', 'alias': 'LONGITUDE'},
#   {'name': 'BID',
#    'type': 'esriFieldTypeString',
#    'alias': 'BID',
#    'length': 100},
#   {'name': 'START_DATE',
#    'type': 'esriFieldTypeDate',
#    'alias': 'START_DATE',
#    'length': 8},
#   {'name': 'END_DATE',
#    'type': 'esriFieldTypeDate',
#    'alias': 'END_DATE',
#    'length': 8},
#   {'name': 'OBJECTID', 'type': 'esriFieldTypeOID', 'alias': 'OBJECTID'},
#   {'name': 'OCTO_RECORD_ID',
#    'type': 'esriFieldTypeString',
#    'alias': 'OCTO_RECORD_ID',
#    'length': 25}],
#  'features': [{'attributes': {'CCN': '20118684',
#     'REPORT_DAT': 1597885268000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '2400 - 2499 BLOCK OF 1ST STREET NW',
#     'XBLOCK': 398946.0,
#     'YBLOCK': 139329.0,
#     'WARD': '5',
#     'ANC': '5E',
#     'DISTRICT': '3',
#     'PSA': '306',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 21',
#     'BLOCK_GROUP': '003301 1',
#     'CENSUS_TRACT': '003301',
#     'VOTING_PRECINCT': 'Precinct 135',
#     'LATITUDE': 38.9218328697,
#     'LONGITUDE': -77.0121544353,
#     'BID': None,
#     'START_DATE': 1597869016000,
#     'END_DATE': 1597875316000,
#     'OBJECTID': 625579101,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.01215672396937, 'y': 38.921840661862966}},
#   {'attributes': {'CCN': '20106669',
#     'REPORT_DAT': 1595763025000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '900 - 999 BLOCK OF L STREET NW',
#     'XBLOCK': 397831.0,
#     'YBLOCK': 137367.0,
#     'WARD': '2',
#     'ANC': '2G',
#     'DISTRICT': '3',
#     'PSA': '307',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 8',
#     'BLOCK_GROUP': '004902 3',
#     'CENSUS_TRACT': '004902',
#     'VOTING_PRECINCT': 'Precinct 129',
#     'LATITUDE': 38.904156468,
#     'LONGITUDE': -77.0250061076,
#     'BID': None,
#     'START_DATE': 1595757880000,
#     'END_DATE': 1595763052000,
#     'OBJECTID': 625579102,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.02500839919232, 'y': 38.904164256145386}},
#   {'attributes': {'CCN': '20167043',
#     'REPORT_DAT': 1606091986000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '1630 - 1699 BLOCK OF EUCLID STREET NW',
#     'XBLOCK': 396671.0,
#     'YBLOCK': 139479.0,
#     'WARD': '1',
#     'ANC': '1C',
#     'DISTRICT': '3',
#     'PSA': '303',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 1',
#     'BLOCK_GROUP': '003802 3',
#     'CENSUS_TRACT': '003802',
#     'VOTING_PRECINCT': 'Precinct 24',
#     'LATITUDE': 38.9231784444,
#     'LONGITUDE': -77.0383898289,
#     'BID': None,
#     'START_DATE': 1606090256000,
#     'END_DATE': None,
#     'OBJECTID': 625579103,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.03839212585768, 'y': 38.92318623583559}},
#   {'attributes': {'CCN': '20127013',
#     'REPORT_DAT': 1599345840000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '1200 - 1399 BLOCK OF DELAWARE AVENUE SW',
#     'XBLOCK': 398747.0,
#     'YBLOCK': 134091.0,
#     'WARD': '6',
#     'ANC': '6D',
#     'DISTRICT': '1',
#     'PSA': '105',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 9',
#     'BLOCK_GROUP': '006400 1',
#     'CENSUS_TRACT': '006400',
#     'VOTING_PRECINCT': 'Precinct 127',
#     'LATITUDE': 38.8746468139,
#     'LONGITUDE': -77.0144396937,
#     'BID': None,
#     'START_DATE': 1598997653000,
#     'END_DATE': 1599339634000,
#     'OBJECTID': 625579104,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.01444198014552, 'y': 38.874654596488966}},
#   {'attributes': {'CCN': '20163565',
#     'REPORT_DAT': 1605501012000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '1821 - 1899 BLOCK OF 3RD STREET NE',
#     'XBLOCK': 399824.0,
#     'YBLOCK': 138591.0,
#     'WARD': '5',
#     'ANC': '5F',
#     'DISTRICT': '5',
#     'PSA': '502',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 21',
#     'BLOCK_GROUP': '008702 3',
#     'CENSUS_TRACT': '008702',
#     'VOTING_PRECINCT': 'Precinct 75',
#     'LATITUDE': 38.915185338,
#     'LONGITUDE': -77.0020293939,
#     'BID': None,
#     'START_DATE': 1605478555000,
#     'END_DATE': 1605482882000,
#     'OBJECTID': 625579122,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.0020316790436, 'y': 38.91519312920307}},
#   {'attributes': {'CCN': '20087101',
#     'REPORT_DAT': 1591992620000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '1000 - 1099 BLOCK OF 18TH STREET NW',
#     'XBLOCK': 396383.0,
#     'YBLOCK': 137254.0,
#     'WARD': '2',
#     'ANC': '2C',
#     'DISTRICT': '2',
#     'PSA': '207',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 6',
#     'BLOCK_GROUP': '010700 1',
#     'CENSUS_TRACT': '010700',
#     'VOTING_PRECINCT': 'Precinct 17',
#     'LATITUDE': 38.9031337585,
#     'LONGITUDE': -77.0416993068,
#     'BID': 'GOLDEN TRIANGLE',
#     'START_DATE': 1591983023000,
#     'END_DATE': 1591990828000,
#     'OBJECTID': 625579141,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.04170160352571, 'y': 38.90314154581578}},
#   {'attributes': {'CCN': '20038338',
#     'REPORT_DAT': 1583265319000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '1100 - 1129 BLOCK OF CONNECTICUT AVENUE NW',
#     'XBLOCK': 396504.0,
#     'YBLOCK': 137376.0,
#     'WARD': '2',
#     'ANC': '2C',
#     'DISTRICT': '2',
#     'PSA': '207',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 6',
#     'BLOCK_GROUP': '010700 1',
#     'CENSUS_TRACT': '010700',
#     'VOTING_PRECINCT': 'Precinct 17',
#     'LATITUDE': 38.904233267,
#     'LONGITUDE': -77.0403049553,
#     'BID': 'GOLDEN TRIANGLE',
#     'START_DATE': 1583262313000,
#     'END_DATE': 1583263247000,
#     'OBJECTID': 625579157,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.04030725166656, 'y': 38.90424105456095}},
#   {'attributes': {'CCN': '20010763',
#     'REPORT_DAT': 1579374076000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '2200 - 2228 BLOCK OF MARTIN LUTHER KING JR AVENUE SE',
#     'XBLOCK': 400867.0,
#     'YBLOCK': 132951.0,
#     'WARD': '8',
#     'ANC': '8A',
#     'DISTRICT': '7',
#     'PSA': '701',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 28',
#     'BLOCK_GROUP': '007503 1',
#     'CENSUS_TRACT': '007503',
#     'VOTING_PRECINCT': 'Precinct 114',
#     'LATITUDE': 38.864377696,
#     'LONGITUDE': -76.9900100454,
#     'BID': 'ANACOSTIA',
#     'START_DATE': 1579366870000,
#     'END_DATE': 1579367222000,
#     'OBJECTID': 625579175,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.99001232370263, 'y': 38.86438547743052}},
#   {'attributes': {'CCN': '20051063',
#     'REPORT_DAT': 1585251851000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'KNIFE',
#     'OFFENSE': 'ASSAULT W/DANGEROUS WEAPON',
#     'BLOCK': '1500 - 1699 BLOCK OF ALABAMA AVENUE SE',
#     'XBLOCK': 401601.0,
#     'YBLOCK': 130970.0,
#     'WARD': '8',
#     'ANC': '8E',
#     'DISTRICT': '7',
#     'PSA': '704',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 38',
#     'BLOCK_GROUP': '007304 4',
#     'CENSUS_TRACT': '007304',
#     'VOTING_PRECINCT': 'Precinct 120',
#     'LATITUDE': 38.8465309715,
#     'LONGITUDE': -76.9815571869,
#     'BID': None,
#     'START_DATE': 1585237021000,
#     'END_DATE': None,
#     'OBJECTID': 625579178,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.98155946146336, 'y': 38.846538749597585}},
#   {'attributes': {'CCN': '20097458',
#     'REPORT_DAT': 1593996814000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '1200 - 1299 BLOCK OF HALF STREET SE',
#     'XBLOCK': 399352.0,
#     'YBLOCK': 134192.0,
#     'WARD': '8',
#     'ANC': '8F',
#     'DISTRICT': '1',
#     'PSA': '106',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 27',
#     'BLOCK_GROUP': '007201 1',
#     'CENSUS_TRACT': '007201',
#     'VOTING_PRECINCT': 'Precinct 131',
#     'LATITUDE': 38.8755573161,
#     'LONGITUDE': -77.0074677102,
#     'BID': 'CAPITOL RIVERFRONT',
#     'START_DATE': 1593992096000,
#     'END_DATE': 1593996831000,
#     'OBJECTID': 625579215,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.00746999454826, 'y': 38.875565099057425}},
#   {'attributes': {'CCN': '20005995',
#     'REPORT_DAT': 1578711926000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '1200 - 1299 BLOCK OF 31ST STREET NW',
#     'XBLOCK': 394691.0,
#     'YBLOCK': 137573.0,
#     'WARD': '2',
#     'ANC': '2E',
#     'DISTRICT': '2',
#     'PSA': '206',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 4',
#     'BLOCK_GROUP': '000102 3',
#     'CENSUS_TRACT': '000102',
#     'VOTING_PRECINCT': 'Precinct 5',
#     'LATITUDE': 38.905998831,
#     'LONGITUDE': -77.0612083276,
#     'BID': 'GEORGETOWN',
#     'START_DATE': 1578691804000,
#     'END_DATE': 1578708003000,
#     'OBJECTID': 625579216,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.0612106305942, 'y': 38.90600661814721}},
#   {'attributes': {'CCN': '20006013',
#     'REPORT_DAT': 1578714907000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '1332  - 1399 BLOCK OF BUCHANAN STREET NW',
#     'XBLOCK': 397225.0,
#     'YBLOCK': 142026.0,
#     'WARD': '4',
#     'ANC': '4E',
#     'DISTRICT': '4',
#     'PSA': '404',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 18',
#     'BLOCK_GROUP': '002501 1',
#     'CENSUS_TRACT': '002501',
#     'VOTING_PRECINCT': 'Precinct 48',
#     'LATITUDE': 38.9461245093,
#     'LONGITUDE': -77.0320114342,
#     'BID': None,
#     'START_DATE': 1578700816000,
#     'END_DATE': 1578711764000,
#     'OBJECTID': 625579217,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.03201373057729, 'y': 38.94613230562809}},
#   {'attributes': {'CCN': '20048211',
#     'REPORT_DAT': 1584656131000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'ROBBERY',
#     'BLOCK': '1 - 98 BLOCK OF NEW YORK AVENUE NE',
#     'XBLOCK': 399352.0,
#     'YBLOCK': 137782.0,
#     'WARD': '6',
#     'ANC': '6E',
#     'DISTRICT': '5',
#     'PSA': '501',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 25',
#     'BLOCK_GROUP': '010601 1',
#     'CENSUS_TRACT': '010601',
#     'VOTING_PRECINCT': 'Precinct 144',
#     'LATITUDE': 38.90789737,
#     'LONGITUDE': -77.0074710961,
#     'BID': 'NOMA',
#     'START_DATE': 1584644441000,
#     'END_DATE': 1584644953000,
#     'OBJECTID': 625579239,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.00747338243013, 'y': 38.907905159505816}},
#   {'attributes': {'CCN': '20048442',
#     'REPORT_DAT': 1584696699000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'BURGLARY',
#     'BLOCK': '400 - 499 BLOCK OF 61ST STREET NE',
#     'XBLOCK': 407489.0,
#     'YBLOCK': 136369.0,
#     'WARD': '7',
#     'ANC': '7C',
#     'DISTRICT': '6',
#     'PSA': '608',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 31',
#     'BLOCK_GROUP': '007808 2',
#     'CENSUS_TRACT': '007808',
#     'VOTING_PRECINCT': 'Precinct 95',
#     'LATITUDE': 38.8951369027,
#     'LONGITUDE': -76.9136712363,
#     'BID': None,
#     'START_DATE': 1584691179000,
#     'END_DATE': 1584691547000,
#     'OBJECTID': 625579240,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.91367349260898, 'y': 38.895144693140324}},
#   {'attributes': {'CCN': '20049254',
#     'REPORT_DAT': 1584837096000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'GUN',
#     'OFFENSE': 'ROBBERY',
#     'BLOCK': '300 - 409 BLOCK OF 50TH STREET NE',
#     'XBLOCK': 406139.0,
#     'YBLOCK': 136306.0,
#     'WARD': '7',
#     'ANC': '7C',
#     'DISTRICT': '6',
#     'PSA': '602',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 31',
#     'BLOCK_GROUP': '007804 2',
#     'CENSUS_TRACT': '007804',
#     'VOTING_PRECINCT': 'Precinct 97',
#     'LATITUDE': 38.8945798398,
#     'LONGITUDE': -76.929233794,
#     'BID': None,
#     'START_DATE': 1584832377000,
#     'END_DATE': 1584835257000,
#     'OBJECTID': 625579241,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.9292360552121, 'y': 38.89458762951195}},
#   {'attributes': {'CCN': '20053292',
#     'REPORT_DAT': 1585695857000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '2200 - 2299 BLOCK OF I STREET NW',
#     'XBLOCK': 395708.0,
#     'YBLOCK': 136984.0,
#     'WARD': '2',
#     'ANC': '2A',
#     'DISTRICT': '2',
#     'PSA': '207',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 5',
#     'BLOCK_GROUP': '005601 3',
#     'CENSUS_TRACT': '005601',
#     'VOTING_PRECINCT': 'Precinct 3',
#     'LATITUDE': 38.9006984662,
#     'LONGITUDE': -77.0494794906,
#     'BID': None,
#     'START_DATE': 1585654221000,
#     'END_DATE': 1585690229000,
#     'OBJECTID': 625579242,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.0494817895438, 'y': 38.90070625272042}},
#   {'attributes': {'CCN': '20151514',
#     'REPORT_DAT': 1603427580000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '4200 - 4399 BLOCK OF NANNIE HELEN BURROUGHS AVENUE NE',
#     'XBLOCK': 405127.0,
#     'YBLOCK': 137046.0,
#     'WARD': '7',
#     'ANC': '7C',
#     'DISTRICT': '6',
#     'PSA': '602',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 30',
#     'BLOCK_GROUP': '007803 1',
#     'CENSUS_TRACT': '007803',
#     'VOTING_PRECINCT': 'Precinct 99',
#     'LATITUDE': 38.9012525106,
#     'LONGITUDE': -76.9408939134,
#     'BID': None,
#     'START_DATE': 1603410592000,
#     'END_DATE': 1603412498000,
#     'OBJECTID': 625579243,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.94089617859598, 'y': 38.901260301296766}},
#   {'attributes': {'CCN': '20401224',
#     'REPORT_DAT': 1598128135000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '500 - 599 BLOCK OF 7TH STREET SE',
#     'XBLOCK': 400331.0,
#     'YBLOCK': 134906.0,
#     'WARD': '6',
#     'ANC': '6B',
#     'DISTRICT': '1',
#     'PSA': '106',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 26',
#     'BLOCK_GROUP': '007000 1',
#     'CENSUS_TRACT': '007000',
#     'VOTING_PRECINCT': 'Precinct 90',
#     'LATITUDE': 38.8819894845,
#     'LONGITUDE': -76.9961851313,
#     'BID': None,
#     'START_DATE': 1598103000000,
#     'END_DATE': 1598112000000,
#     'OBJECTID': 625579244,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.9961874125945, 'y': 38.88199726918401}},
#   {'attributes': {'CCN': '20401232',
#     'REPORT_DAT': 1598376557000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '3800  - 3899 BLOCK OF 13TH STREET NW',
#     'XBLOCK': 397424.0,
#     'YBLOCK': 141139.0,
#     'WARD': '4',
#     'ANC': '4C',
#     'DISTRICT': '4',
#     'PSA': '404',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 18',
#     'BLOCK_GROUP': '002504 1',
#     'CENSUS_TRACT': '002504',
#     'VOTING_PRECINCT': 'Precinct 47',
#     'LATITUDE': 38.9381347643,
#     'LONGITUDE': -77.0297125093,
#     'BID': None,
#     'START_DATE': 1598234400000,
#     'END_DATE': 1598272200000,
#     'OBJECTID': 625579245,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.02971480445271, 'y': 38.93814255910475}},
#   {'attributes': {'CCN': '20129126',
#     'REPORT_DAT': 1599694572000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'BURGLARY',
#     'BLOCK': '5300 - 5399 BLOCK OF C STREET SE',
#     'XBLOCK': 406505.0,
#     'YBLOCK': 135193.0,
#     'WARD': '7',
#     'ANC': '7E',
#     'DISTRICT': '6',
#     'PSA': '604',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 33',
#     'BLOCK_GROUP': '009905 1',
#     'CENSUS_TRACT': '009905',
#     'VOTING_PRECINCT': 'Precinct 105',
#     'LATITUDE': 38.8845508896,
#     'LONGITUDE': -76.9250253346,
#     'BID': None,
#     'START_DATE': 1599684673000,
#     'END_DATE': None,
#     'OBJECTID': 625579251,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.92502759381931, 'y': 38.884558677447586}},
#   {'attributes': {'CCN': '20172053',
#     'REPORT_DAT': 1607019991000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '2811 - 2998 BLOCK OF BLADENSBURG ROAD NE',
#     'XBLOCK': 403272.0,
#     'YBLOCK': 139963.0,
#     'WARD': '5',
#     'ANC': '5C',
#     'DISTRICT': '5',
#     'PSA': '503',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 24',
#     'BLOCK_GROUP': '011100 1',
#     'CENSUS_TRACT': '011100',
#     'VOTING_PRECINCT': 'Precinct 71',
#     'LATITUDE': 38.9275386834,
#     'LONGITUDE': -76.9622651844,
#     'BID': None,
#     'START_DATE': 1604761259000,
#     'END_DATE': 1607020005000,
#     'OBJECTID': 625579255,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.96226745789286, 'y': 38.92754647853064}},
#   {'attributes': {'CCN': '20177299',
#     'REPORT_DAT': 1608008087000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '7200  - 7299 BLOCK OF BLAIR ROAD NW',
#     'XBLOCK': 398175.0,
#     'YBLOCK': 145505.0,
#     'WARD': '4',
#     'ANC': '4B',
#     'DISTRICT': '4',
#     'PSA': '401',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 17',
#     'BLOCK_GROUP': '010300 3',
#     'CENSUS_TRACT': '010300',
#     'VOTING_PRECINCT': 'Precinct 63',
#     'LATITUDE': 38.9774667093,
#     'LONGITUDE': -77.0210618246,
#     'BID': None,
#     'START_DATE': 1607981968000,
#     'END_DATE': 1607984585000,
#     'OBJECTID': 625579256,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.02106411945901, 'y': 38.97747451235791}},
#   {'attributes': {'CCN': '20060001',
#     'REPORT_DAT': 1587130022000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '420 - 499 BLOCK OF 53RD STREET SE',
#     'XBLOCK': 406362.0,
#     'YBLOCK': 134947.0,
#     'WARD': '7',
#     'ANC': '7E',
#     'DISTRICT': '6',
#     'PSA': '604',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 33',
#     'BLOCK_GROUP': '009905 3',
#     'CENSUS_TRACT': '009905',
#     'VOTING_PRECINCT': 'Precinct 104',
#     'LATITUDE': 38.882335874,
#     'LONGITUDE': -76.926675786,
#     'BID': None,
#     'START_DATE': 1586980811000,
#     'END_DATE': 1586985015000,
#     'OBJECTID': 625579257,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.92667804566442, 'y': 38.88234366135406}},
#   {'attributes': {'CCN': '20061917',
#     'REPORT_DAT': 1587531715000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '1400 - 1499 BLOCK OF W STREET NW',
#     'XBLOCK': 397113.0,
#     'YBLOCK': 139035.0,
#     'WARD': '1',
#     'ANC': '1B',
#     'DISTRICT': '3',
#     'PSA': '301',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 3',
#     'BLOCK_GROUP': '004300 2',
#     'CENSUS_TRACT': '004300',
#     'VOTING_PRECINCT': 'Precinct 22',
#     'LATITUDE': 38.9191803122,
#     'LONGITUDE': -77.0332908446,
#     'BID': None,
#     'START_DATE': 1587250812000,
#     'END_DATE': 1587348015000,
#     'OBJECTID': 625579258,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.03329313972648, 'y': 38.91918810304283}},
#   {'attributes': {'CCN': '20062282',
#     'REPORT_DAT': 1587607324000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'KNIFE',
#     'OFFENSE': 'ASSAULT W/DANGEROUS WEAPON',
#     'BLOCK': '2100 - 2199 BLOCK OF I STREET NE',
#     'XBLOCK': 402339.0,
#     'YBLOCK': 137267.0,
#     'WARD': '5',
#     'ANC': '5D',
#     'DISTRICT': '5',
#     'PSA': '507',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 23',
#     'BLOCK_GROUP': '008904 3',
#     'CENSUS_TRACT': '008904',
#     'VOTING_PRECINCT': 'Precinct 79',
#     'LATITUDE': 38.9032551969,
#     'LONGITUDE': -76.973034326,
#     'BID': None,
#     'START_DATE': 1587599410000,
#     'END_DATE': 1587606253000,
#     'OBJECTID': 625579259,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.97303660137943, 'y': 38.90326298676108}},
#   {'attributes': {'CCN': '20033198',
#     'REPORT_DAT': 1582532628000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '600 - 699 BLOCK OF GALVESTON STREET SE',
#     'XBLOCK': 400084.0,
#     'YBLOCK': 128443.0,
#     'WARD': '8',
#     'ANC': '8E',
#     'DISTRICT': '7',
#     'PSA': '706',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 39',
#     'BLOCK_GROUP': '009811 3',
#     'CENSUS_TRACT': '009811',
#     'VOTING_PRECINCT': 'Precinct 125',
#     'LATITUDE': 38.8237680529,
#     'LONGITUDE': -76.9990326655,
#     'BID': None,
#     'START_DATE': 1582330127000,
#     'END_DATE': 1582380689000,
#     'OBJECTID': 625579267,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.99903494413469, 'y': 38.82377582571473}},
#   {'attributes': {'CCN': '20099366',
#     'REPORT_DAT': 1594358204000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '1900 BLOCK OF D STREET SE',
#     'XBLOCK': 402061.0,
#     'YBLOCK': 135138.0,
#     'WARD': '7',
#     'ANC': '7F',
#     'DISTRICT': '1',
#     'PSA': '107',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 26',
#     'BLOCK_GROUP': '006804 1',
#     'CENSUS_TRACT': '006804',
#     'VOTING_PRECINCT': 'Precinct 80',
#     'LATITUDE': 38.8840770766,
#     'LONGITUDE': -76.9762456966,
#     'BID': None,
#     'START_DATE': 1594292416000,
#     'END_DATE': 1594358247000,
#     'OBJECTID': 625579269,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.97624797175848, 'y': 38.884084862494284}},
#   {'attributes': {'CCN': '20103250',
#     'REPORT_DAT': 1595111427000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '1200 - 1219 BLOCK OF CONNECTICUT AVENUE NW',
#     'XBLOCK': 396412.0,
#     'YBLOCK': 137579.0,
#     'WARD': '2',
#     'ANC': '2B',
#     'DISTRICT': '2',
#     'PSA': '208',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 6',
#     'BLOCK_GROUP': '010700 2',
#     'CENSUS_TRACT': '010700',
#     'VOTING_PRECINCT': 'Precinct 17',
#     'LATITUDE': 38.9060615912,
#     'LONGITUDE': -77.0413666724,
#     'BID': 'GOLDEN TRIANGLE',
#     'START_DATE': 1594661426000,
#     'END_DATE': 1594663230000,
#     'OBJECTID': 625579270,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.04136896920126, 'y': 38.90606937905136}},
#   {'attributes': {'CCN': '20164853',
#     'REPORT_DAT': 1605718258000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '3100 - 3299 BLOCK OF 14TH STREET NW',
#     'XBLOCK': 397162.0,
#     'YBLOCK': 140182.0,
#     'WARD': '1',
#     'ANC': '1A',
#     'DISTRICT': '3',
#     'PSA': '302',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 2',
#     'BLOCK_GROUP': '002802 1',
#     'CENSUS_TRACT': '002802',
#     'VOTING_PRECINCT': 'Precinct 39',
#     'LATITUDE': 38.9295130123,
#     'LONGITUDE': -77.0327305535,
#     'BID': None,
#     'START_DATE': 1605713388000,
#     'END_DATE': 1605717508000,
#     'OBJECTID': 625579283,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.03273284903338, 'y': 38.929520805242326}},
#   {'attributes': {'CCN': '20038242',
#     'REPORT_DAT': 1583255866000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '1300 - 1399 BLOCK OF H STREET NE',
#     'XBLOCK': 401135.0,
#     'YBLOCK': 136927.0,
#     'WARD': '6',
#     'ANC': '6A',
#     'DISTRICT': '1',
#     'PSA': '104',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 25',
#     'BLOCK_GROUP': '008410 1',
#     'CENSUS_TRACT': '008410',
#     'VOTING_PRECINCT': 'Precinct 82',
#     'LATITUDE': 38.9001947352,
#     'LONGITUDE': -76.9869154654,
#     'BID': None,
#     'START_DATE': 1583253815000,
#     'END_DATE': None,
#     'OBJECTID': 625579284,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.98691774483964, 'y': 38.900202523960864}},
#   {'attributes': {'CCN': '20137064',
#     'REPORT_DAT': 1601063222000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '4924 - 4949 BLOCK OF CENTRAL AVENUE NE',
#     'XBLOCK': 405990.0,
#     'YBLOCK': 135788.0,
#     'WARD': '7',
#     'ANC': '7C',
#     'DISTRICT': '6',
#     'PSA': '608',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 33',
#     'BLOCK_GROUP': '007804 3',
#     'CENSUS_TRACT': '007804',
#     'VOTING_PRECINCT': 'Precinct 97',
#     'LATITUDE': 38.8899145329,
#     'LONGITUDE': -76.9309558799,
#     'BID': None,
#     'START_DATE': 1600938939000,
#     'END_DATE': 1601063232000,
#     'OBJECTID': 625579288,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.93095814135401, 'y': 38.88992232159536}},
#   {'attributes': {'CCN': '20137743',
#     'REPORT_DAT': 1601876682000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '1500 - 1599 BLOCK OF FORT DAVIS PLACE SE',
#     'XBLOCK': 404688.0,
#     'YBLOCK': 133377.0,
#     'WARD': '7',
#     'ANC': '7B',
#     'DISTRICT': '6',
#     'PSA': '605',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 34',
#     'BLOCK_GROUP': '009902 2',
#     'CENSUS_TRACT': '009902',
#     'VOTING_PRECINCT': 'Precinct 110',
#     'LATITUDE': 38.8682032114,
#     'LONGITUDE': -76.9459799077,
#     'BID': None,
#     'START_DATE': 1601168212000,
#     'END_DATE': 1601173242000,
#     'OBJECTID': 625579289,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.94598217251144, 'y': 38.86821099514668}},
#   {'attributes': {'CCN': '20058713',
#     'REPORT_DAT': 1586852017000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'BURGLARY',
#     'BLOCK': '710 - 798 BLOCK OF ALABAMA AVENUE SE',
#     'XBLOCK': 400432.0,
#     'YBLOCK': 130639.0,
#     'WARD': '8',
#     'ANC': '8C',
#     'DISTRICT': '7',
#     'PSA': '705',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 39',
#     'BLOCK_GROUP': '010400 1',
#     'CENSUS_TRACT': '010400',
#     'VOTING_PRECINCT': 'Precinct 123',
#     'LATITUDE': 38.8435505277,
#     'LONGITUDE': -76.9950237585,
#     'BID': None,
#     'START_DATE': 1586838137000,
#     'END_DATE': 1586844791000,
#     'OBJECTID': 625579292,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.99502603708713, 'y': 38.84355830467124}},
#   {'attributes': {'CCN': '20130124',
#     'REPORT_DAT': 1599874853000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '1700 - 1799 BLOCK OF K STREET NW',
#     'XBLOCK': 396481.17,
#     'YBLOCK': 137186.37,
#     'WARD': '2',
#     'ANC': '2C',
#     'DISTRICT': '2',
#     'PSA': '207',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 6',
#     'BLOCK_GROUP': '010700 1',
#     'CENSUS_TRACT': '010700',
#     'VOTING_PRECINCT': 'Precinct 17',
#     'LATITUDE': 38.9025249221,
#     'LONGITUDE': -77.040567188,
#     'BID': 'GOLDEN TRIANGLE',
#     'START_DATE': 1599830885000,
#     'END_DATE': 1599834612000,
#     'OBJECTID': 625579310,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.04056948435732, 'y': 38.902532709298725}},
#   {'attributes': {'CCN': '20013799',
#     'REPORT_DAT': 1579828085000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '750 - 799 BLOCK OF 10TH STREET NW',
#     'XBLOCK': 397745.0,
#     'YBLOCK': 136842.0,
#     'WARD': '2',
#     'ANC': '2C',
#     'DISTRICT': '2',
#     'PSA': '209',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 8',
#     'BLOCK_GROUP': '005802 5',
#     'CENSUS_TRACT': '005802',
#     'VOTING_PRECINCT': 'Precinct 129',
#     'LATITUDE': 38.8994268651,
#     'LONGITUDE': -77.0259958663,
#     'BID': 'DOWNTOWN',
#     'START_DATE': 1578891637000,
#     'END_DATE': 1578977989000,
#     'OBJECTID': 625579327,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.02599815793604, 'y': 38.899434652253376}},
#   {'attributes': {'CCN': '20037574',
#     'REPORT_DAT': 1583161775000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '2300 - 2499 BLOCK OF 11TH STREET NW',
#     'XBLOCK': 397655.0,
#     'YBLOCK': 139302.0,
#     'WARD': '1',
#     'ANC': '1B',
#     'DISTRICT': '3',
#     'PSA': '304',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 2',
#     'BLOCK_GROUP': '003500 2',
#     'CENSUS_TRACT': '003500',
#     'VOTING_PRECINCT': 'Precinct 37',
#     'LATITUDE': 38.9215871483,
#     'LONGITUDE': -77.027041796,
#     'BID': None,
#     'START_DATE': 1582925404000,
#     'END_DATE': 1583155821000,
#     'OBJECTID': 625579329,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.02704408922847, 'y': 38.92159493983564}},
#   {'attributes': {'CCN': '20040731',
#     'REPORT_DAT': 1583577423000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'GUN',
#     'OFFENSE': 'ASSAULT W/DANGEROUS WEAPON',
#     'BLOCK': '2701 - 2899 BLOCK OF HARTFORD STREET SE',
#     'XBLOCK': 402810.0,
#     'YBLOCK': 131849.0,
#     'WARD': '8',
#     'ANC': '8B',
#     'DISTRICT': '7',
#     'PSA': '702',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 36',
#     'BLOCK_GROUP': '007502 3',
#     'CENSUS_TRACT': '007502',
#     'VOTING_PRECINCT': 'Precinct 115',
#     'LATITUDE': 38.8544463542,
#     'LONGITUDE': -76.9676264508,
#     'BID': None,
#     'START_DATE': 1583572808000,
#     'END_DATE': 1583577442000,
#     'OBJECTID': 625579330,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.96762872149613, 'y': 38.85445413444263}},
#   {'attributes': {'CCN': '20041143',
#     'REPORT_DAT': 1583633098000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'ROBBERY',
#     'BLOCK': '1200 - 1229 BLOCK OF 1ST STREET NE',
#     'XBLOCK': 399489.0,
#     'YBLOCK': 137576.0,
#     'WARD': '6',
#     'ANC': '6E',
#     'DISTRICT': '5',
#     'PSA': '501',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 25',
#     'BLOCK_GROUP': '010601 2',
#     'CENSUS_TRACT': '010601',
#     'VOTING_PRECINCT': 'Precinct 144',
#     'LATITUDE': 38.9060417408,
#     'LONGITUDE': -77.0058914055,
#     'BID': 'NOMA',
#     'START_DATE': 1583630172000,
#     'END_DATE': 1583630413000,
#     'OBJECTID': 625579331,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.00589369126273, 'y': 38.90604953000705}},
#   {'attributes': {'CCN': '20149174',
#     'REPORT_DAT': 1603050770000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '4026 - 4199 BLOCK OF WHEELER ROAD SE',
#     'XBLOCK': 400887.0,
#     'YBLOCK': 129540.0,
#     'WARD': '8',
#     'ANC': '8E',
#     'DISTRICT': '7',
#     'PSA': '706',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 39',
#     'BLOCK_GROUP': '009801 1',
#     'CENSUS_TRACT': '009801',
#     'VOTING_PRECINCT': 'Precinct 121',
#     'LATITUDE': 38.8336498975,
#     'LONGITUDE': -76.989783995,
#     'BID': None,
#     'START_DATE': 1603049895000,
#     'END_DATE': 1603050700000,
#     'OBJECTID': 625579022,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.98978627135064, 'y': 38.83365767270833}},
#   {'attributes': {'CCN': '20078429',
#     'REPORT_DAT': 1590621087000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '600 - 699 BLOCK OF CONSTITUTION AVENUE NE',
#     'XBLOCK': 400233.0,
#     'YBLOCK': 136018.0,
#     'WARD': '6',
#     'ANC': '6C',
#     'DISTRICT': '1',
#     'PSA': '108',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 25',
#     'BLOCK_GROUP': '008200 1',
#     'CENSUS_TRACT': '008200',
#     'VOTING_PRECINCT': 'Precinct 85',
#     'LATITUDE': 38.8920068336,
#     'LONGITUDE': -76.997314232,
#     'BID': None,
#     'START_DATE': 1590379293000,
#     'END_DATE': 1590593405000,
#     'OBJECTID': 625579023,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.99731651422672, 'y': 38.89201462025681}},
#   {'attributes': {'CCN': '20088924',
#     'REPORT_DAT': 1592329652000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '900 - 999 BLOCK OF N STREET NW',
#     'XBLOCK': 397833.0,
#     'YBLOCK': 137709.0,
#     'WARD': '2',
#     'ANC': '2G',
#     'DISTRICT': '3',
#     'PSA': '307',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 7',
#     'BLOCK_GROUP': '004902 2',
#     'CENSUS_TRACT': '004902',
#     'VOTING_PRECINCT': 'Precinct 129',
#     'LATITUDE': 38.9072373283,
#     'LONGITUDE': -77.024984129,
#     'BID': None,
#     'START_DATE': 1591891231000,
#     'END_DATE': 1592323247000,
#     'OBJECTID': 625579025,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.02498642074309, 'y': 38.90724511702041}},
#   {'attributes': {'CCN': '20023780',
#     'REPORT_DAT': 1581187929000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '700 - 799 BLOCK OF 13TH STREET SE',
#     'XBLOCK': 401014.0,
#     'YBLOCK': 134725.0,
#     'WARD': '6',
#     'ANC': '6B',
#     'DISTRICT': '1',
#     'PSA': '106',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 26',
#     'BLOCK_GROUP': '007100 3',
#     'CENSUS_TRACT': '007100',
#     'VOTING_PRECINCT': 'Precinct 91',
#     'LATITUDE': 38.8803584438,
#     'LONGITUDE': -76.9883136302,
#     'BID': 'CAPITOL HILL',
#     'START_DATE': 1581116447000,
#     'END_DATE': 1581185013000,
#     'OBJECTID': 625579038,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.98831590889586, 'y': 38.88036622847891}},
#   {'attributes': {'CCN': '20024035',
#     'REPORT_DAT': 1581224172000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '5000 - 5099 BLOCK OF AMES STREET NE',
#     'XBLOCK': 406158.0,
#     'YBLOCK': 135884.0,
#     'WARD': '7',
#     'ANC': '7C',
#     'DISTRICT': '6',
#     'PSA': '608',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 33',
#     'BLOCK_GROUP': '007804 3',
#     'CENSUS_TRACT': '007804',
#     'VOTING_PRECINCT': 'Precinct 97',
#     'LATITUDE': 38.8907781758,
#     'LONGITUDE': -76.9290185575,
#     'BID': None,
#     'START_DATE': 1581215226000,
#     'END_DATE': 1581219027000,
#     'OBJECTID': 625579039,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.92902081837435, 'y': 38.89078596479103}},
#   {'attributes': {'CCN': '20027533',
#     'REPORT_DAT': 1581716626000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '400 - 599 BLOCK OF C STREET SW',
#     'XBLOCK': 398374.0,
#     'YBLOCK': 135355.0,
#     'WARD': '6',
#     'ANC': '6D',
#     'DISTRICT': '1',
#     'PSA': '103',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 9',
#     'BLOCK_GROUP': '010202 1',
#     'CENSUS_TRACT': '010202',
#     'VOTING_PRECINCT': 'Precinct 142',
#     'LATITUDE': 38.8860328076,
#     'LONGITUDE': -77.0187411722,
#     'BID': 'SOUTHWEST',
#     'START_DATE': 1581714822000,
#     'END_DATE': 1581714970000,
#     'OBJECTID': 625579040,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.01874346072495, 'y': 38.88604059228594}},
#   {'attributes': {'CCN': '20029202',
#     'REPORT_DAT': 1581979935000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'KNIFE',
#     'OFFENSE': 'ASSAULT W/DANGEROUS WEAPON',
#     'BLOCK': '100 - 199 BLOCK OF 47TH STREET NE',
#     'XBLOCK': 405649.0,
#     'YBLOCK': 135917.0,
#     'WARD': '7',
#     'ANC': '7F',
#     'DISTRICT': '6',
#     'PSA': '608',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 33',
#     'BLOCK_GROUP': '007804 3',
#     'CENSUS_TRACT': '007804',
#     'VOTING_PRECINCT': 'Precinct 98',
#     'LATITUDE': 38.89107887,
#     'LONGITUDE': -76.9348853764,
#     'BID': None,
#     'START_DATE': 1581969638000,
#     'END_DATE': 1581973230000,
#     'OBJECTID': 625579041,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.93488763909573, 'y': 38.89108665879322}},
#   {'attributes': {'CCN': '20030183',
#     'REPORT_DAT': 1582119839000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '4501 - 4599 BLOCK OF VAN NESS STREET NW',
#     'XBLOCK': 392230.0,
#     'YBLOCK': 141700.0,
#     'WARD': '3',
#     'ANC': '3E',
#     'DISTRICT': '2',
#     'PSA': '202',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 11',
#     'BLOCK_GROUP': '001004 3',
#     'CENSUS_TRACT': '001004',
#     'VOTING_PRECINCT': 'Precinct 30',
#     'LATITUDE': 38.9431578311,
#     'LONGITUDE': -77.0896282985,
#     'BID': None,
#     'START_DATE': 1582064150000,
#     'END_DATE': 1582118701000,
#     'OBJECTID': 625579042,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.08963061263037, 'y': 38.9431656246006}},
#   {'attributes': {'CCN': '20157717',
#     'REPORT_DAT': 1604499816000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '700 - 799 BLOCK OF N STREET NW',
#     'XBLOCK': 398054.0,
#     'YBLOCK': 137708.0,
#     'WARD': '2',
#     'ANC': '2G',
#     'DISTRICT': '3',
#     'PSA': '307',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 7',
#     'BLOCK_GROUP': '004902 2',
#     'CENSUS_TRACT': '004902',
#     'VOTING_PRECINCT': 'Precinct 18',
#     'LATITUDE': 38.907228837,
#     'LONGITUDE': -77.0224361371,
#     'BID': None,
#     'START_DATE': 1604499335000,
#     'END_DATE': 1604499637000,
#     'OBJECTID': 625579052,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.02243842806601, 'y': 38.90723662584439}},
#   {'attributes': {'CCN': '20029249',
#     'REPORT_DAT': 1581985094000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '1500 - 1599 BLOCK OF INDEPENDENCE AVENUE SE',
#     'XBLOCK': 401480.0,
#     'YBLOCK': 135528.0,
#     'WARD': '7',
#     'ANC': '7D',
#     'DISTRICT': '1',
#     'PSA': '107',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 26',
#     'BLOCK_GROUP': '006801 2',
#     'CENSUS_TRACT': '006801',
#     'VOTING_PRECINCT': 'Precinct 87',
#     'LATITUDE': 38.8875915151,
#     'LONGITUDE': -76.9829412418,
#     'BID': None,
#     'START_DATE': 1580402854000,
#     'END_DATE': 1580403057000,
#     'OBJECTID': 625579053,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.9829435192947, 'y': 38.887599301448404}},
#   {'attributes': {'CCN': '20113108',
#     'REPORT_DAT': 1596897731000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '200  - 298 BLOCK OF JEFFERSON STREET NW',
#     'XBLOCK': 398724.0,
#     'YBLOCK': 143069.0,
#     'WARD': '4',
#     'ANC': '4D',
#     'DISTRICT': '4',
#     'PSA': '403',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 18',
#     'BLOCK_GROUP': '002102 4',
#     'CENSUS_TRACT': '002102',
#     'VOTING_PRECINCT': 'Precinct 57',
#     'LATITUDE': 38.9555235941,
#     'LONGITUDE': -77.0147214327,
#     'BID': None,
#     'START_DATE': 1596895574000,
#     'END_DATE': None,
#     'OBJECTID': 625579054,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.01472372418458, 'y': 38.95553139290775}},
#   {'attributes': {'CCN': '20113241',
#     'REPORT_DAT': 1596933743000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '3200 - 3275 BLOCK OF M STREET NW',
#     'XBLOCK': 394449.0,
#     'YBLOCK': 137479.0,
#     'WARD': '2',
#     'ANC': '2E',
#     'DISTRICT': '2',
#     'PSA': '206',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 4',
#     'BLOCK_GROUP': '000202 3',
#     'CENSUS_TRACT': '000202',
#     'VOTING_PRECINCT': 'Precinct 6',
#     'LATITUDE': 38.9051505514,
#     'LONGITUDE': -77.0639976245,
#     'BID': 'GEORGETOWN',
#     'START_DATE': 1596913844000,
#     'END_DATE': 1596914712000,
#     'OBJECTID': 625579055,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.06399992826547, 'y': 38.90515833823093}},
#   {'attributes': {'CCN': '20145527',
#     'REPORT_DAT': 1602441962000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '1201 - 1249 BLOCK OF PENNSYLVANIA AVENUE SE',
#     'XBLOCK': 400930.0,
#     'YBLOCK': 134891.0,
#     'WARD': '6',
#     'ANC': '6B',
#     'DISTRICT': '1',
#     'PSA': '106',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 26',
#     'BLOCK_GROUP': '007100 2',
#     'CENSUS_TRACT': '007100',
#     'VOTING_PRECINCT': 'Precinct 91',
#     'LATITUDE': 38.8818539291,
#     'LONGITUDE': -76.9892815072,
#     'BID': 'CAPITOL HILL',
#     'START_DATE': 1602438586000,
#     'END_DATE': 1602438718000,
#     'OBJECTID': 625579068,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.98928378628992, 'y': 38.88186171407592}},
#   {'attributes': {'CCN': '20087308',
#     'REPORT_DAT': 1592020381000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'KNIFE',
#     'OFFENSE': 'ASSAULT W/DANGEROUS WEAPON',
#     'BLOCK': '800 - 811 BLOCK OF BLADENSBURG ROAD NE',
#     'XBLOCK': 401462.0,
#     'YBLOCK': 136955.0,
#     'WARD': '5',
#     'ANC': '5D',
#     'DISTRICT': '5',
#     'PSA': '506',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 23',
#     'BLOCK_GROUP': '008802 2',
#     'CENSUS_TRACT': '008802',
#     'VOTING_PRECINCT': 'Precinct 77',
#     'LATITUDE': 38.9004464862,
#     'LONGITUDE': -76.9831456765,
#     'BID': None,
#     'START_DATE': 1592014802000,
#     'END_DATE': None,
#     'OBJECTID': 625579075,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.98314795479936, 'y': 38.90045427513181}},
#   {'attributes': {'CCN': '20031443',
#     'REPORT_DAT': 1582296373000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '4510 - 4549 BLOCK OF BENNING ROAD SE',
#     'XBLOCK': 405443.0,
#     'YBLOCK': 135696.0,
#     'WARD': '7',
#     'ANC': '7E',
#     'DISTRICT': '6',
#     'PSA': '604',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 33',
#     'BLOCK_GROUP': '009906 1',
#     'CENSUS_TRACT': '009906',
#     'VOTING_PRECINCT': 'Precinct 103',
#     'LATITUDE': 38.8890893192,
#     'LONGITUDE': -76.9372616373,
#     'BID': None,
#     'START_DATE': 1582289735000,
#     'END_DATE': None,
#     'OBJECTID': 625580186,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.93726390064056, 'y': 38.889097107571594}},
#   {'attributes': {'CCN': '20032348',
#     'REPORT_DAT': 1582412249000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '3036 - 3099 BLOCK OF M STREET NW',
#     'XBLOCK': 394737.0,
#     'YBLOCK': 137483.0,
#     'WARD': '2',
#     'ANC': '2E',
#     'DISTRICT': '2',
#     'PSA': '206',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 4',
#     'BLOCK_GROUP': '000102 3',
#     'CENSUS_TRACT': '000102',
#     'VOTING_PRECINCT': 'Precinct 5',
#     'LATITUDE': 38.9051883564,
#     'LONGITUDE': -77.0606772966,
#     'BID': 'GEORGETOWN',
#     'START_DATE': 1582406430000,
#     'END_DATE': 1582407028000,
#     'OBJECTID': 625580187,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.06067959934288, 'y': 38.90519614337519}},
#   {'attributes': {'CCN': '20152650',
#     'REPORT_DAT': 1603724390000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '400 - 499 BLOCK OF FLORIDA AVENUE NE',
#     'XBLOCK': 400003.0,
#     'YBLOCK': 137674.0,
#     'WARD': '6',
#     'ANC': '6C',
#     'DISTRICT': '5',
#     'PSA': '501',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 25',
#     'BLOCK_GROUP': '010602 4',
#     'CENSUS_TRACT': '010602',
#     'VOTING_PRECINCT': 'Precinct 83',
#     'LATITUDE': 38.9069247074,
#     'LONGITUDE': -76.9999654121,
#     'BID': None,
#     'START_DATE': 1602999059000,
#     'END_DATE': 1603000801000,
#     'OBJECTID': 625580267,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.99996769601351, 'y': 38.90693249703798}},
#   {'attributes': {'CCN': '20035671',
#     'REPORT_DAT': 1582861729000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '900 - 999 BLOCK OF 12TH STREET NW',
#     'XBLOCK': 397564.0,
#     'YBLOCK': 137119.0,
#     'WARD': '2',
#     'ANC': '2C',
#     'DISTRICT': '2',
#     'PSA': '209',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 8',
#     'BLOCK_GROUP': '010100 2',
#     'CENSUS_TRACT': '010100',
#     'VOTING_PRECINCT': 'Precinct 129',
#     'LATITUDE': 38.9019216971,
#     'LONGITUDE': -77.0280834347,
#     'BID': 'DOWNTOWN',
#     'START_DATE': 1582844433000,
#     'END_DATE': 1582858828000,
#     'OBJECTID': 625580273,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.0280857271412, 'y': 38.9019294846042}},
#   {'attributes': {'CCN': '20069296',
#     'REPORT_DAT': 1588967365000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '700 - 799 BLOCK OF N STREET NW',
#     'XBLOCK': 398054.0,
#     'YBLOCK': 137708.0,
#     'WARD': '2',
#     'ANC': '2G',
#     'DISTRICT': '3',
#     'PSA': '307',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 7',
#     'BLOCK_GROUP': '004902 2',
#     'CENSUS_TRACT': '004902',
#     'VOTING_PRECINCT': 'Precinct 18',
#     'LATITUDE': 38.907228837,
#     'LONGITUDE': -77.0224361371,
#     'BID': None,
#     'START_DATE': 1588957259000,
#     'END_DATE': 1588957613000,
#     'OBJECTID': 625580274,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.02243842806601, 'y': 38.90723662584439}},
#   {'attributes': {'CCN': '20169201',
#     'REPORT_DAT': 1606508676000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'ASSAULT W/DANGEROUS WEAPON',
#     'BLOCK': '500 - 721 BLOCK OF 2ND STREET NW',
#     'XBLOCK': 398815.0,
#     'YBLOCK': 136650.0,
#     'WARD': '6',
#     'ANC': '6E',
#     'DISTRICT': '1',
#     'PSA': '102',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 8',
#     'BLOCK_GROUP': '005900 2',
#     'CENSUS_TRACT': '005900',
#     'VOTING_PRECINCT': 'Precinct 1',
#     'LATITUDE': 38.8976993535,
#     'LONGITUDE': -77.013660468,
#     'BID': 'DOWNTOWN',
#     'START_DATE': 1606502604000,
#     'END_DATE': 1606507255000,
#     'OBJECTID': 625580287,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.01366275564523, 'y': 38.89770714074349}},
#   {'attributes': {'CCN': '20170226',
#     'REPORT_DAT': 1606706651000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '800 - 819 BLOCK OF 46TH STREET NE',
#     'XBLOCK': 405500.0,
#     'YBLOCK': 136936.0,
#     'WARD': '7',
#     'ANC': '7C',
#     'DISTRICT': '6',
#     'PSA': '602',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 31',
#     'BLOCK_GROUP': '007809 2',
#     'CENSUS_TRACT': '007809',
#     'VOTING_PRECINCT': 'Precinct 94',
#     'LATITUDE': 38.9002593369,
#     'LONGITUDE': -76.9365947038,
#     'BID': None,
#     'START_DATE': 1606608003000,
#     'END_DATE': 1606676413000,
#     'OBJECTID': 625580288,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.93659696758839, 'y': 38.90026712750309}},
#   {'attributes': {'CCN': '20158943',
#     'REPORT_DAT': 1604695300000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'MOTOR VEHICLE THEFT',
#     'BLOCK': '600 - 629 BLOCK OF KENILWORTH TERRACE NE',
#     'XBLOCK': 404308.0,
#     'YBLOCK': 136738.0,
#     'WARD': '7',
#     'ANC': '7D',
#     'DISTRICT': '6',
#     'PSA': '601',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 30',
#     'BLOCK_GROUP': '009602 3',
#     'CENSUS_TRACT': '009602',
#     'VOTING_PRECINCT': 'Precinct 100',
#     'LATITUDE': 38.8984823319,
#     'LONGITUDE': -76.9503375994,
#     'BID': None,
#     'START_DATE': 1604620803000,
#     'END_DATE': 1604695345000,
#     'OBJECTID': 625580305,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.9503398673658, 'y': 38.89849012168309}},
#   {'attributes': {'CCN': '20159059',
#     'REPORT_DAT': 1604709694000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'GUN',
#     'OFFENSE': 'ROBBERY',
#     'BLOCK': '6100 - 6199 BLOCK OF BANKS PLACE NE',
#     'XBLOCK': 407549.0,
#     'YBLOCK': 136017.0,
#     'WARD': '7',
#     'ANC': '7C',
#     'DISTRICT': '6',
#     'PSA': '608',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 31',
#     'BLOCK_GROUP': '007808 2',
#     'CENSUS_TRACT': '007808',
#     'VOTING_PRECINCT': 'Precinct 96',
#     'LATITUDE': 38.8919654451,
#     'LONGITUDE': -76.9129834599,
#     'BID': None,
#     'START_DATE': 1604703639000,
#     'END_DATE': 1604704842000,
#     'OBJECTID': 625580306,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.91298571586111, 'y': 38.89197323496148}},
#   {'attributes': {'CCN': '20401488',
#     'REPORT_DAT': 1601151237000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '700 - 799 BLOCK OF N STREET NW',
#     'XBLOCK': 398054.0,
#     'YBLOCK': 137708.0,
#     'WARD': '2',
#     'ANC': '2G',
#     'DISTRICT': '3',
#     'PSA': '307',
# ...
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '934 - 1099 BLOCK OF EASTERN AVENUE NE',
#     'XBLOCK': 406683.0,
#     'YBLOCK': 137294.0,
#     'WARD': '7',
#     'ANC': '7C',
#     'DISTRICT': '6',
#     'PSA': '608',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 31',
#     'BLOCK_GROUP': '007807 2',
#     'CENSUS_TRACT': '007807',
#     'VOTING_PRECINCT': 'Precinct 95',
#     'LATITUDE': 38.9034761291,
#     'LONGITUDE': -76.9229533236,
#     'BID': None,
#     'START_DATE': 1590721473000,
#     'END_DATE': None,
#     'OBJECTID': 625054703,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.92295558339136, 'y': 38.9034839208861}},
#   {'attributes': {'CCN': '20079314',
#     'REPORT_DAT': 1590771741000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'SEX ABUSE',
#     'BLOCK': '4600 - 4899 BLOCK OF B STREET SE',
#     'XBLOCK': 405711.0,
#     'YBLOCK': 135520.0,
#     'WARD': '7',
#     'ANC': '7E',
#     'DISTRICT': '6',
#     'PSA': '604',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 33',
#     'BLOCK_GROUP': '009906 1',
#     'CENSUS_TRACT': '009906',
#     'VOTING_PRECINCT': 'Precinct 104',
#     'LATITUDE': 38.8875021452,
#     'LONGITUDE': -76.9341740177,
#     'BID': None,
#     'START_DATE': 1590762275000,
#     'END_DATE': 1590764416000,
#     'OBJECTID': 625054704,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.93417627999361, 'y': 38.887509933352064}},
#   {'attributes': {'CCN': '20079578',
#     'REPORT_DAT': 1590805358000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '3400 - 3478 BLOCK OF SUMMIT COURT NE',
#     'XBLOCK': 403561.0,
#     'YBLOCK': 140013.0,
#     'WARD': '5',
#     'ANC': '5C',
#     'DISTRICT': '5',
#     'PSA': '503',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 24',
#     'BLOCK_GROUP': '009000 1',
#     'CENSUS_TRACT': '009000',
#     'VOTING_PRECINCT': 'Precinct 139',
#     'LATITUDE': 38.9279879753,
#     'LONGITUDE': -76.9589319909,
#     'BID': None,
#     'START_DATE': 1590163206000,
#     'END_DATE': 1590418826000,
#     'OBJECTID': 625054705,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.95893426339843, 'y': 38.92799577066872}},
#   {'attributes': {'CCN': '20079807',
#     'REPORT_DAT': 1595780509000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '2400 - 2479 BLOCK OF 16TH STREET NW',
#     'XBLOCK': 396835.0,
#     'YBLOCK': 139331.0,
#     'WARD': '1',
#     'ANC': '1C',
#     'DISTRICT': '3',
#     'PSA': '303',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 1',
#     'BLOCK_GROUP': '003801 1',
#     'CENSUS_TRACT': '003801',
#     'VOTING_PRECINCT': 'Precinct 24',
#     'LATITUDE': 38.9218458189,
#     'LONGITUDE': -77.0364979086,
#     'BID': None,
#     'START_DATE': 1588521630000,
#     'END_DATE': 1588521935000,
#     'OBJECTID': 625054706,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.03650020483605, 'y': 38.921853610147366}},
#   {'attributes': {'CCN': '20079842',
#     'REPORT_DAT': 1590859707000,
#     'SHIFT': 'DAY',
#     'METHOD': 'GUN',
#     'OFFENSE': 'ASSAULT W/DANGEROUS WEAPON',
#     'BLOCK': '4310 - 4399 BLOCK OF E STREET SE',
#     'XBLOCK': 405182.0,
#     'YBLOCK': 135041.0,
#     'WARD': '7',
#     'ANC': '7E',
#     'DISTRICT': '6',
#     'PSA': '605',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 33',
#     'BLOCK_GROUP': '009907 2',
#     'CENSUS_TRACT': '009907',
#     'VOTING_PRECINCT': 'Precinct 103',
#     'LATITUDE': 38.8831904084,
#     'LONGITUDE': -76.9402749743,
#     'BID': None,
#     'START_DATE': 1590856434000,
#     'END_DATE': 1590856540000,
#     'OBJECTID': 625054707,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.94027723819607, 'y': 38.88319819538729}},
#   {'attributes': {'CCN': '20080526',
#     'REPORT_DAT': 1590956952000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '400 - 499 BLOCK OF M STREET SE',
#     'XBLOCK': 399995.0,
#     'YBLOCK': 134294.0,
#     'WARD': '8',
#     'ANC': '8F',
#     'DISTRICT': '1',
#     'PSA': '106',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 27',
#     'BLOCK_GROUP': '007203 1',
#     'CENSUS_TRACT': '007203',
#     'VOTING_PRECINCT': 'Precinct 131',
#     'LATITUDE': 38.8764764112,
#     'LONGITUDE': -77.000057622,
#     'BID': 'CAPITOL RIVERFRONT',
#     'START_DATE': 1590692424000,
#     'END_DATE': 1590788731000,
#     'OBJECTID': 625054708,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.00005990408386, 'y': 38.87648419469543}},
#   {'attributes': {'CCN': '20080841',
#     'REPORT_DAT': 1590998491000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'BURGLARY',
#     'BLOCK': '3200 - 3299 BLOCK OF PENNSYLVANIA AVENUE SE',
#     'XBLOCK': 403516.0,
#     'YBLOCK': 133455.0,
#     'WARD': '7',
#     'ANC': '7B',
#     'DISTRICT': '6',
#     'PSA': '605',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 34',
#     'BLOCK_GROUP': '009901 2',
#     'CENSUS_TRACT': '009901',
#     'VOTING_PRECINCT': 'Precinct 109',
#     'LATITUDE': 38.8689113338,
#     'LONGITUDE': -76.9594845298,
#     'BID': None,
#     'START_DATE': 1590990647000,
#     'END_DATE': 1590994666000,
#     'OBJECTID': 625054709,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.95948679885501, 'y': 38.868919117200804}},
#   {'attributes': {'CCN': '20080975',
#     'REPORT_DAT': 1591013431000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'BURGLARY',
#     'BLOCK': '3036 - 3099 BLOCK OF M STREET NW',
#     'XBLOCK': 394737.0,
#     'YBLOCK': 137483.0,
#     'WARD': '2',
#     'ANC': '2E',
#     'DISTRICT': '2',
#     'PSA': '206',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 4',
#     'BLOCK_GROUP': '000102 3',
#     'CENSUS_TRACT': '000102',
#     'VOTING_PRECINCT': 'Precinct 5',
#     'LATITUDE': 38.9051883564,
#     'LONGITUDE': -77.0606772966,
#     'BID': 'GEORGETOWN',
#     'START_DATE': 1591008395000,
#     'END_DATE': 1591012040000,
#     'OBJECTID': 625054710,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.06067959934288, 'y': 38.90519614337519}},
#   {'attributes': {'CCN': '20081086',
#     'REPORT_DAT': 1591026740000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'BURGLARY',
#     'BLOCK': '2301 - 2499 BLOCK OF WISCONSIN AVENUE NW',
#     'XBLOCK': 393731.0,
#     'YBLOCK': 139295.0,
#     'WARD': '3',
#     'ANC': '3B',
#     'DISTRICT': '2',
#     'PSA': '204',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 14',
#     'BLOCK_GROUP': '000300 1',
#     'CENSUS_TRACT': '000300',
#     'VOTING_PRECINCT': 'Precinct 11',
#     'LATITUDE': 38.9215048581,
#     'LONGITUDE': -77.072292042,
#     'BID': None,
#     'START_DATE': 1590989738000,
#     'END_DATE': 1590989942000,
#     'OBJECTID': 625054711,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.07229434933886, 'y': 38.92151264789122}},
#   {'attributes': {'CCN': '20102986',
#     'REPORT_DAT': 1595043781000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '4200 - 4399 BLOCK OF NANNIE HELEN BURROUGHS AVENUE NE',
#     'XBLOCK': 405127.0,
#     'YBLOCK': 137046.0,
#     'WARD': '7',
#     'ANC': '7C',
#     'DISTRICT': '6',
#     'PSA': '602',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 30',
#     'BLOCK_GROUP': '007803 1',
#     'CENSUS_TRACT': '007803',
#     'VOTING_PRECINCT': 'Precinct 99',
#     'LATITUDE': 38.9012525106,
#     'LONGITUDE': -76.9408939134,
#     'BID': None,
#     'START_DATE': 1595037983000,
#     'END_DATE': None,
#     'OBJECTID': 625055077,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.94089617859598, 'y': 38.901260301296766}},
#   {'attributes': {'CCN': '20103045',
#     'REPORT_DAT': 1595053469000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '200 - 225 BLOCK OF 11TH STREET NE',
#     'XBLOCK': 400734.0,
#     'YBLOCK': 136062.0,
#     'WARD': '6',
#     'ANC': '6A',
#     'DISTRICT': '1',
#     'PSA': '108',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 25',
#     'BLOCK_GROUP': '008100 2',
#     'CENSUS_TRACT': '008100',
#     'VOTING_PRECINCT': 'Precinct 85',
#     'LATITUDE': 38.8924029264,
#     'LONGITUDE': -76.9915392075,
#     'BID': None,
#     'START_DATE': 1595053004000,
#     'END_DATE': None,
#     'OBJECTID': 625055078,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.99154148795031, 'y': 38.89241071333708}},
#   {'attributes': {'CCN': '20103337',
#     'REPORT_DAT': 1595119628000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'GUN',
#     'OFFENSE': 'ASSAULT W/DANGEROUS WEAPON',
#     'BLOCK': '3800 - 3899 BLOCK OF HALLEY TERRACE SE',
#     'XBLOCK': 399380.0,
#     'YBLOCK': 129543.0,
#     'WARD': '8',
#     'ANC': '8D',
#     'DISTRICT': '7',
#     'PSA': '707',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 39',
#     'BLOCK_GROUP': '009803 3',
#     'CENSUS_TRACT': '009803',
#     'VOTING_PRECINCT': 'Precinct 124',
#     'LATITUDE': 38.8336771516,
#     'LONGITUDE': -77.0071408405,
#     'BID': None,
#     'START_DATE': 1595111272000,
#     'END_DATE': 1595116817000,
#     'OBJECTID': 625055079,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.0071431221836, 'y': 38.8336849261048}},
#   {'attributes': {'CCN': '20103991',
#     'REPORT_DAT': 1595257006000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '3820 - 3899 BLOCK OF GARFIELD STREET NW',
#     'XBLOCK': 393371.0,
#     'YBLOCK': 139964.0,
#     'WARD': '3',
#     'ANC': '3A',
#     'DISTRICT': '2',
#     'PSA': '204',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 14',
#     'BLOCK_GROUP': '000704 2',
#     'CENSUS_TRACT': '000704',
#     'VOTING_PRECINCT': 'Precinct 28',
#     'LATITUDE': 38.9275287788,
#     'LONGITUDE': -77.0764499021,
#     'BID': None,
#     'START_DATE': 1594933259000,
#     'END_DATE': 1594981809000,
#     'OBJECTID': 625055080,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.07645221116483, 'y': 38.92753656974132}},
#   {'attributes': {'CCN': '20105474',
#     'REPORT_DAT': 1595537189000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'GUN',
#     'OFFENSE': 'ASSAULT W/DANGEROUS WEAPON',
#     'BLOCK': '4500 - 4599 BLOCK OF QUARLES STREET NE',
#     'XBLOCK': 405550.0,
#     'YBLOCK': 138194.0,
#     'WARD': '7',
#     'ANC': '7D',
#     'DISTRICT': '6',
#     'PSA': '601',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 29',
#     'BLOCK_GROUP': '009601 1',
#     'CENSUS_TRACT': '009601',
#     'VOTING_PRECINCT': 'Precinct 92',
#     'LATITUDE': 38.9115915227,
#     'LONGITUDE': -76.9360081261,
#     'BID': None,
#     'START_DATE': 1595531335000,
#     'END_DATE': None,
#     'OBJECTID': 625055081,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.93601039045183, 'y': 38.91159931560476}},
#   {'attributes': {'CCN': '20072891',
#     'REPORT_DAT': 1589639354000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '4300 - 4339 BLOCK OF F STREET SE',
#     'XBLOCK': 404990.0,
#     'YBLOCK': 134891.0,
#     'WARD': '7',
#     'ANC': '7E',
#     'DISTRICT': '6',
#     'PSA': '605',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 33',
#     'BLOCK_GROUP': '009907 1',
#     'CENSUS_TRACT': '009907',
#     'VOTING_PRECINCT': 'Precinct 103',
#     'LATITUDE': 38.8818402613,
#     'LONGITUDE': -76.9424889546,
#     'BID': None,
#     'START_DATE': 1586955632000,
#     'END_DATE': 1589547643000,
#     'OBJECTID': 625055462,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.94249121907937, 'y': 38.88184804798754}},
#   {'attributes': {'CCN': '20023007',
#     'REPORT_DAT': 1581084547000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '5200 - 5399 BLOCK OF ROCK CREEK CHURCH ROAD NE',
#     'XBLOCK': 399362.0,
#     'YBLOCK': 142931.0,
#     'WARD': '5',
#     'ANC': '5A',
#     'DISTRICT': '4',
#     'PSA': '405',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 19',
#     'BLOCK_GROUP': '009508 4',
#     'CENSUS_TRACT': '009508',
#     'VOTING_PRECINCT': 'Precinct 44',
#     'LATITUDE': 38.9542811485,
#     'LONGITUDE': -77.007360588,
#     'BID': None,
#     'START_DATE': 1581069616000,
#     'END_DATE': 1581081344000,
#     'OBJECTID': 625054729,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.00736287715641, 'y': 38.95428894737934}},
#   {'attributes': {'CCN': '20023181',
#     'REPORT_DAT': 1581166026000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '5400  - 5499 BLOCK OF 1ST PLACE NW',
#     'XBLOCK': 399122.0,
#     'YBLOCK': 143126.0,
#     'WARD': '4',
#     'ANC': '4B',
#     'DISTRICT': '4',
#     'PSA': '406',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 17',
#     'BLOCK_GROUP': '002102 2',
#     'CENSUS_TRACT': '002102',
#     'VOTING_PRECINCT': 'Precinct 57',
#     'LATITUDE': 38.9560375531,
#     'LONGITUDE': -77.0101297109,
#     'BID': None,
#     'START_DATE': 1581103485000,
#     'END_DATE': 1581106287000,
#     'OBJECTID': 625054730,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.01013200097496, 'y': 38.95604535224248}},
#   {'attributes': {'CCN': '20024254',
#     'REPORT_DAT': 1581259526000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '2700 - 2799 BLOCK OF FAIRLAWN AVENUE SE',
#     'XBLOCK': 402707.0,
#     'YBLOCK': 134220.0,
#     'WARD': '7',
#     'ANC': '7B',
#     'DISTRICT': '6',
#     'PSA': '605',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 34',
#     'BLOCK_GROUP': '007709 1',
#     'CENSUS_TRACT': '007709',
#     'VOTING_PRECINCT': 'Precinct 111',
#     'LATITUDE': 38.8758056232,
#     'LONGITUDE': -76.9688037621,
#     'BID': None,
#     'START_DATE': 1581252374000,
#     'END_DATE': 1581254059000,
#     'OBJECTID': 625054731,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.96880603444866, 'y': 38.87581340772362}},
#   {'attributes': {'CCN': '20024649',
#     'REPORT_DAT': 1581310517000,
#     'SHIFT': 'MIDNIGHT',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '2500 - 2598 BLOCK OF BENNING ROAD NE',
#     'XBLOCK': 402530.0,
#     'YBLOCK': 136674.0,
#     'WARD': '7',
#     'ANC': '7D',
#     'DISTRICT': '5',
#     'PSA': '507',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 25',
#     'BLOCK_GROUP': '007903 1',
#     'CENSUS_TRACT': '007903',
#     'VOTING_PRECINCT': 'Precinct 80',
#     'LATITUDE': 38.8979127122,
#     'LONGITUDE': -76.970834525,
#     'BID': None,
#     'START_DATE': 1581309014000,
#     'END_DATE': 1581309283000,
#     'OBJECTID': 625054732,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.97083679934742, 'y': 38.8979205010324}},
#   {'attributes': {'CCN': '20025463',
#     'REPORT_DAT': 1581449182000,
#     'SHIFT': 'DAY',
#     'METHOD': 'GUN',
#     'OFFENSE': 'ASSAULT W/DANGEROUS WEAPON',
#     'BLOCK': '1300 - 1399 BLOCK OF COLUMBIA ROAD NW',
#     'XBLOCK': 397302.0,
#     'YBLOCK': 139967.0,
#     'WARD': '1',
#     'ANC': '1A',
#     'DISTRICT': '3',
#     'PSA': '302',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 2',
#     'BLOCK_GROUP': '003000 2',
#     'CENSUS_TRACT': '003000',
#     'VOTING_PRECINCT': 'Precinct 39',
#     'LATITUDE': 38.9275766665,
#     'LONGITUDE': -77.0311150934,
#     'BID': None,
#     'START_DATE': 1581439968000,
#     'END_DATE': None,
#     'OBJECTID': 625054733,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.03111738834663, 'y': 38.92758445912173}},
#   {'attributes': {'CCN': '20025704',
#     'REPORT_DAT': 1581474094000,
#     'SHIFT': 'EVENING',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT/OTHER',
#     'BLOCK': '4600 - 4799 BLOCK OF HAYES STREET NE',
#     'XBLOCK': 405622.0,
#     'YBLOCK': 136876.0,
#     'WARD': '7',
#     'ANC': '7C',
#     'DISTRICT': '6',
#     'PSA': '602',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 31',
#     'BLOCK_GROUP': '007809 2',
#     'CENSUS_TRACT': '007809',
#     'VOTING_PRECINCT': 'Precinct 94',
#     'LATITUDE': 38.8997180637,
#     'LONGITUDE': -76.9351887506,
#     'BID': None,
#     'START_DATE': 1581466148000,
#     'END_DATE': 1581466799000,
#     'OBJECTID': 625054734,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -76.93519101390805, 'y': 38.89972585427287}},
#   {'attributes': {'CCN': '20026004',
#     'REPORT_DAT': 1581522807000,
#     'SHIFT': 'DAY',
#     'METHOD': 'OTHERS',
#     'OFFENSE': 'THEFT F/AUTO',
#     'BLOCK': '1802 - 1899 BLOCK OF 11TH STREET NW',
#     'XBLOCK': 397655.0,
#     'YBLOCK': 138573.0,
#     'WARD': '1',
#     'ANC': '1B',
#     'DISTRICT': '3',
#     'PSA': '305',
#     'NEIGHBORHOOD_CLUSTER': 'Cluster 3',
#     'BLOCK_GROUP': '004402 1',
#     'CENSUS_TRACT': '004402',
#     'VOTING_PRECINCT': 'Precinct 137',
#     'LATITUDE': 38.9150200771,
#     'LONGITUDE': -77.0270393059,
#     'BID': None,
#     'START_DATE': 1581474612000,
#     'END_DATE': 1581511502000,
#     'OBJECTID': 625054735,
#     'OCTO_RECORD_ID': None},
#    'geometry': {'x': -77.02704159882437, 'y': 38.91502786734728}}],
#  'exceededTransferLimit': True}

# %% [markdown]
# # **Step 4 - Normalize the data dict into a DataFrame**

# %%
# normalize the data dict and read it into a dataframe
# in this dataset, the data to extract is under 'features'

df = pd.json_normalize(data, 'features')

# print the first rows and header of the dataframe
df.head(10)
# Out:
#   attributes.CCN  attributes.REPORT_DAT attributes.SHIFT attributes.METHOD  \
# 0       20118684          1597885268000          EVENING            OTHERS
# 1       20106669          1595763025000              DAY            OTHERS
# 2       20167043          1606091986000          EVENING            OTHERS
# 3       20127013          1599345840000          EVENING            OTHERS
# 4       20163565          1605501012000         MIDNIGHT            OTHERS
# 5       20087101          1591992620000          EVENING            OTHERS
# 6       20038338          1583265319000              DAY            OTHERS
# 7       20010763          1579374076000              DAY            OTHERS
# 8       20051063          1585251851000          EVENING             KNIFE
# 9       20097458          1593996814000          EVENING            OTHERS
#
#            attributes.OFFENSE  \
# 0         MOTOR VEHICLE THEFT
# 1                 THEFT/OTHER
# 2         MOTOR VEHICLE THEFT
# 3         MOTOR VEHICLE THEFT
# 4         MOTOR VEHICLE THEFT
# 5                 THEFT/OTHER
# 6                 THEFT/OTHER
# 7                THEFT F/AUTO
# 8  ASSAULT W/DANGEROUS WEAPON
# 9                 THEFT/OTHER
#
#                                     attributes.BLOCK  attributes.XBLOCK  \
# 0                 2400 - 2499 BLOCK OF 1ST STREET NW           398946.0
# 1                     900 - 999 BLOCK OF L STREET NW           397831.0
# 2              1630 - 1699 BLOCK OF EUCLID STREET NW           396671.0
# 3            1200 - 1399 BLOCK OF DELAWARE AVENUE SW           398747.0
# 4                 1821 - 1899 BLOCK OF 3RD STREET NE           399824.0
# 5                1000 - 1099 BLOCK OF 18TH STREET NW           396383.0
# 6         1100 - 1129 BLOCK OF CONNECTICUT AVENUE NW           396504.0
# 7  2200 - 2228 BLOCK OF MARTIN LUTHER KING JR AVE...           400867.0
# 8             1500 - 1699 BLOCK OF ALABAMA AVENUE SE           401601.0
# 9                1200 - 1299 BLOCK OF HALF STREET SE           399352.0
#
#    attributes.YBLOCK attributes.WARD attributes.ANC  ...  \
# 0           139329.0               5             5E  ...
# 1           137367.0               2             2G  ...
# 2           139479.0               1             1C  ...
# 3           134091.0               6             6D  ...
# 4           138591.0               5             5F  ...
# 5           137254.0               2             2C  ...
# 6           137376.0               2             2C  ...
# 7           132951.0               8             8A  ...
# 8           130970.0               8             8E  ...
# 9           134192.0               8             8F  ...
#
#   attributes.VOTING_PRECINCT attributes.LATITUDE attributes.LONGITUDE  \
# 0               Precinct 135           38.921833           -77.012154
# 1               Precinct 129           38.904156           -77.025006
# 2                Precinct 24           38.923178           -77.038390
# 3               Precinct 127           38.874647           -77.014440
# 4                Precinct 75           38.915185           -77.002029
# 5                Precinct 17           38.903134           -77.041699
# 6                Precinct 17           38.904233           -77.040305
# 7               Precinct 114           38.864378           -76.990010
# 8               Precinct 120           38.846531           -76.981557
# 9               Precinct 131           38.875557           -77.007468
#
#        attributes.BID attributes.START_DATE attributes.END_DATE  \
# 0                None         1597869016000        1.597875e+12
# 1                None         1595757880000        1.595763e+12
# 2                None         1606090256000                 NaN
# 3                None         1598997653000        1.599340e+12
# 4                None         1605478555000        1.605483e+12
# 5     GOLDEN TRIANGLE         1591983023000        1.591991e+12
# 6     GOLDEN TRIANGLE         1583262313000        1.583263e+12
# 7           ANACOSTIA         1579366870000        1.579367e+12
# 8                None         1585237021000                 NaN
# 9  CAPITOL RIVERFRONT         1593992096000        1.593997e+12
#
#    attributes.OBJECTID  attributes.OCTO_RECORD_ID geometry.x  geometry.y
# 0            625579101                       None -77.012157   38.921841
# 1            625579102                       None -77.025008   38.904164
# 2            625579103                       None -77.038392   38.923186
# 3            625579104                       None -77.014442   38.874655
# 4            625579122                       None -77.002032   38.915193
# 5            625579141                       None -77.041702   38.903142
# 6            625579157                       None -77.040307   38.904241
# 7            625579175                       None -76.990012   38.864385
# 8            625579178                       None -76.981559   38.846539
# 9            625579215                       None -77.007470   38.875565
#
# [10 rows x 25 columns]

# %%
df.shape
# Out:
# (1000, 25)
