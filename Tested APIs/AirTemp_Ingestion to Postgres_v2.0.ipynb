# %%
# Updates in v2.0
# updated for hourly intervals with datetime library on timedelta(hours=1)
# included parameters for hours and minutes in start_date and end_date(yyyy, mm, dd, hh, mm)
# updated date_time_str = current_date.strftime("%Y-%m-%dT%H:%M:%S")

# %%
# !pip install sqlalchemy
# !pip install psycopg2
# !pip install sqlalchemy_utils
# Out:
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/lib/python3.12/site-packages (2.0.30)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: psycopg2 in /opt/anaconda3/lib/python3.12/site-packages (2.9.10)
# Collecting sqlalchemy_utils
#   Downloading SQLAlchemy_Utils-0.41.2-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: SQLAlchemy>=1.3 in /opt/anaconda3/lib/python3.12/site-packages (from sqlalchemy_utils) (2.0.30)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from SQLAlchemy>=1.3->sqlalchemy_utils) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from SQLAlchemy>=1.3->sqlalchemy_utils) (3.0.1)
# Downloading SQLAlchemy_Utils-0.41.2-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 1.8 MB/s eta 0:00:0000:01
# Installing collected packages: sqlalchemy_utils
# Successfully installed sqlalchemy_utils-0.41.2

# %%
import requests  # For sending HTTP requests
import pandas as pd  # For data manipulation
from datetime import datetime, timedelta  # For handling dates
from sqlalchemy import create_engine, text  # For database operations

# Define constants
API_URL = "https://api.data.gov.sg/v1/environment/air-temperature"
DB_USER = 'postgres'  # Update with your PostgreSQL username
DB_PASS = 'admin'      # Update with your PostgreSQL password
DB_HOST = 'localhost'  # Update with your database host
DB_PORT = '5432'       # Update with your database port
DB_NAME = 'data_gov_project'  # Update with your PostgreSQL database name
START_DATE = datetime(2023, 10, 1, 0, 0)  # start_date = datetime(yyyy, mm, dd, hh, mm)
END_DATE = datetime(2023, 11, 1, 23, 0)  # end_date = datetime(yyyy, mm, dd, hh, mm)

def fetch_air_temperature_data(api_url, start_date, end_date):
    """Fetch air temperature data from the API for a given date range."""
    data_frames = []  # List to store DataFrames for each day's temperature readings
    current_date = start_date

    while current_date <= end_date:
        # Format current date for the API request
        date_time_str = current_date.strftime("%Y-%m-%dT%H:%M:%S")
        params = {"date_time": date_time_str}

        # Send a GET request to the API
        response = requests.get(api_url, params=params)

        if response.status_code == 200:
            json_data = response.json()
            print(json_data)  # Debugging: Print the full JSON response
            items = json_data.get("items", [])

            if not items:
                print(f"No data returned for {date_time_str}.")
            else:
                # Process the readings from the data structure
                process_items(items, json_data, data_frames)  # Pass json_data here
        else:
            print(f"Failed to fetch data for {date_time_str}. Status code: {response.status_code}")

        current_date += timedelta(hours=1)

    return data_frames

def process_items(items, json_data, data_frames):
    """Process the fetched items and store temperature readings in DataFrames."""
    for item in items:
        readings = item.get('readings', [])
        timestamp = item.get('timestamp')  # Access the timestamp from the current item

        for sensor in readings:
            # Creating a DataFrame for each reading
            airtemp_df = create_reading_dataframe(sensor, timestamp)

            # Get station metadata
            station_metadata = get_station_metadata(sensor['station_id'], json_data)
            if station_metadata:
                station_info(airtemp_df, station_metadata)

            # Append the list of DataFrames
            data_frames.append(airtemp_df)

def create_reading_dataframe(sensor, timestamp):
    """Create a DataFrame from the reading."""
    return pd.DataFrame({
       'station_id': [sensor['station_id']],
        'temperature': [sensor['value']],
        'timestamp': [timestamp]  # Use the timestamp from the item directly
    })

def get_station_metadata(station_id, json_data):
    """Fetch station metadata for a given station ID."""
    for station in json_data['metadata']['stations']:
        if station['id'] == station_id:
            return {
                'name': station['name'],
                'latitude': station['location']['latitude'],
                'longitude': station['location']['longitude']
            }
    return None

def station_info(df, station_metadata):
    """Add latitude, longitude, and station_name to the DataFrame."""
    df['latitude'] = station_metadata.get('latitude')
    df['longitude'] = station_metadata.get('longitude')
    df['station_name'] = station_metadata.get('name')

def load_data_to_postgres(data_frame):
    """
    Load the provided pandas DataFrame into the 'air_temperature' table in your PostgreSQL database.
    """
    engine = create_engine(f'postgresql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}')
    try:
        data_frame.to_sql('air_temperature', engine, if_exists='append', index=False)  # Append mode
        print(f"Successfully loaded {len(data_frame)} records to PostgreSQL table.")
    except Exception as e:
        print(f"Error loading data into PostgreSQL: {e}")
        
def verify_data_in_db():
    """
    Retrieves number of rows from 'air_temperature' table to verify data was loaded successfully.
    """
    engine = create_engine(f'postgresql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}')
    try:
        with engine.connect() as connection:
            result = connection.execute(text("SELECT COUNT(*) FROM air_temperature"))
            count = result.fetchone()[0]
            print(f"Total records in 'air_temperature' table: {count}")  # Show count of rows
    except Exception as e:
        print(f"Error verifying data in PostgreSQL: {e}")

def verify_database_connection():
    """
    Verifies the database connection by printing a message if successful.
    """
    engine = create_engine(f'postgresql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}')
    try:
        with engine.connect() as connection:
            print("Database connection successful")
    except Exception as e:
        print(f"Error connecting to PostgreSQL: {e}")

def create_table():
    """
    Creates the 'air_temperature' table in the database.
    """
    engine = create_engine(f'postgresql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}')
    try:
        with engine.connect() as connection:
            connection.execute(text("""
                CREATE TABLE IF NOT EXISTS air_temperature (
                    id SERIAL PRIMARY KEY,
                    timestamp TIMESTAMP,
                    temperature REAL,
                    station_id VARCHAR(255),
                    station_name VARCHAR(255),
                    latitude REAL,
                    longitude REAL
                )
            """))
            print("Table created successfully")
    except Exception as e:
        print(f"Error creating table in PostgreSQL: {e}")

def main():
    print("Starting the script...")

    verify_database_connection() # Verify database connection

    create_table() # Create the table

    data_frames = fetch_air_temperature_data(API_URL, START_DATE, END_DATE) # Fetch the data
    print(f"Fetched data frames: {len(data_frames)}")

    if data_frames:
        combined_df = pd.concat(data_frames, ignore_index=True)

        # Clean up DataFrame
        combined_df['timestamp'] = pd.to_datetime(combined_df['timestamp'])  # Convert timestamp to datetime
        combined_df = combined_df.loc[:, ~combined_df.columns.duplicated()]  # Remove duplicates
        combined_df = combined_df[['timestamp', 'temperature','station_id','station_name', 'latitude', 'longitude']]  # Rearrange columns

        load_data_to_postgres(combined_df) # Load the data into PostgreSQL

        verify_data_in_db() # Verify the data in the database
    else:
        print("No data collected.")
    
    print("Script completed.")

if __name__ == "__main__":
    main()
# Out:
# Starting the script...
# Database connection successful
# Table created successfully
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T00:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 26.7}, {'station_id': 'S117', 'value': 27.7}, {'station_id': 'S50', 'value': 27}, {'station_id': 'S107', 'value': 27.9}, {'station_id': 'S43', 'value': 27.9}, {'station_id': 'S44', 'value': 26.9}, {'station_id': 'S121', 'value': 26.7}, {'station_id': 'S111', 'value': 27.2}, {'station_id': 'S60', 'value': 27.7}, {'station_id': 'S115', 'value': 27.7}, {'station_id': 'S24', 'value': 26.9}, {'station_id': 'S116', 'value': 28.1}, {'station_id': 'S104', 'value': 26.9}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T01:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 26.5}, {'station_id': 'S117', 'value': 27.9}, {'station_id': 'S50', 'value': 26.6}, {'station_id': 'S107', 'value': 27.9}, {'station_id': 'S43', 'value': 27.7}, {'station_id': 'S44', 'value': 26.7}, {'station_id': 'S121', 'value': 26.4}, {'station_id': 'S111', 'value': 26.9}, {'station_id': 'S60', 'value': 27.3}, {'station_id': 'S115', 'value': 27.8}, {'station_id': 'S24', 'value': 26.4}, {'station_id': 'S116', 'value': 27.9}, {'station_id': 'S104', 'value': 26.4}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T02:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 26.3}, {'station_id': 'S117', 'value': 27.6}, {'station_id': 'S50', 'value': 26.3}, {'station_id': 'S107', 'value': 27.4}, {'station_id': 'S43', 'value': 27.4}, {'station_id': 'S44', 'value': 26.3}, {'station_id': 'S121', 'value': 26.2}, {'station_id': 'S111', 'value': 26.6}, {'station_id': 'S60', 'value': 27}, {'station_id': 'S115', 'value': 27.1}, {'station_id': 'S24', 'value': 26.3}, {'station_id': 'S116', 'value': 27.5}, {'station_id': 'S104', 'value': 25.6}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T03:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 26.2}, {'station_id': 'S117', 'value': 27.3}, {'station_id': 'S50', 'value': 26.2}, {'station_id': 'S107', 'value': 27.1}, {'station_id': 'S43', 'value': 27.4}, {'station_id': 'S44', 'value': 25.7}, {'station_id': 'S121', 'value': 25.9}, {'station_id': 'S111', 'value': 26.5}, {'station_id': 'S60', 'value': 27.1}, {'station_id': 'S115', 'value': 27.1}, {'station_id': 'S24', 'value': 26.3}, {'station_id': 'S116', 'value': 27.5}, {'station_id': 'S104', 'value': 25.7}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T04:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 25.8}, {'station_id': 'S117', 'value': 27}, {'station_id': 'S50', 'value': 26.2}, {'station_id': 'S107', 'value': 27.9}, {'station_id': 'S43', 'value': 27.1}, {'station_id': 'S44', 'value': 25.6}, {'station_id': 'S121', 'value': 25.5}, {'station_id': 'S111', 'value': 25.9}, {'station_id': 'S60', 'value': 27}, {'station_id': 'S115', 'value': 26.8}, {'station_id': 'S24', 'value': 26.4}, {'station_id': 'S116', 'value': 27.1}, {'station_id': 'S104', 'value': 25.7}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T05:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 26.4}, {'station_id': 'S117', 'value': 26.6}, {'station_id': 'S50', 'value': 26}, {'station_id': 'S107', 'value': 27.9}, {'station_id': 'S43', 'value': 27.2}, {'station_id': 'S44', 'value': 25.7}, {'station_id': 'S121', 'value': 25.6}, {'station_id': 'S111', 'value': 26}, {'station_id': 'S60', 'value': 26.6}, {'station_id': 'S115', 'value': 26.8}, {'station_id': 'S24', 'value': 26.3}, {'station_id': 'S116', 'value': 27.7}, {'station_id': 'S104', 'value': 26.1}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T06:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 26.2}, {'station_id': 'S117', 'value': 27}, {'station_id': 'S50', 'value': 26.2}, {'station_id': 'S107', 'value': 27.6}, {'station_id': 'S43', 'value': 27.7}, {'station_id': 'S44', 'value': 25.3}, {'station_id': 'S121', 'value': 25.6}, {'station_id': 'S111', 'value': 26.4}, {'station_id': 'S60', 'value': 27}, {'station_id': 'S115', 'value': 26.8}, {'station_id': 'S24', 'value': 26.5}, {'station_id': 'S116', 'value': 27.5}, {'station_id': 'S104', 'value': 25.9}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T07:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 26.1}, {'station_id': 'S117', 'value': 26.8}, {'station_id': 'S50', 'value': 26.1}, {'station_id': 'S107', 'value': 27.7}, {'station_id': 'S43', 'value': 27.7}, {'station_id': 'S44', 'value': 25.3}, {'station_id': 'S121', 'value': 25.6}, {'station_id': 'S111', 'value': 26.3}, {'station_id': 'S60', 'value': 26.7}, {'station_id': 'S115', 'value': 26.6}, {'station_id': 'S24', 'value': 26.3}, {'station_id': 'S116', 'value': 27.4}, {'station_id': 'S104', 'value': 25.5}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T08:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 27.2}, {'station_id': 'S117', 'value': 27.2}, {'station_id': 'S50', 'value': 26.4}, {'station_id': 'S107', 'value': 28.6}, {'station_id': 'S43', 'value': 27.8}, {'station_id': 'S44', 'value': 25.8}, {'station_id': 'S121', 'value': 26.1}, {'station_id': 'S111', 'value': 27.3}, {'station_id': 'S60', 'value': 28}, {'station_id': 'S115', 'value': 26.9}, {'station_id': 'S24', 'value': 27.4}, {'station_id': 'S104', 'value': 25.8}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T09:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 28.8}, {'station_id': 'S117', 'value': 29}, {'station_id': 'S50', 'value': 29.5}, {'station_id': 'S107', 'value': 29.9}, {'station_id': 'S43', 'value': 29.1}, {'station_id': 'S44', 'value': 27.8}, {'station_id': 'S121', 'value': 28}, {'station_id': 'S111', 'value': 29.9}, {'station_id': 'S60', 'value': 30.2}, {'station_id': 'S115', 'value': 27.9}, {'station_id': 'S24', 'value': 28.6}, {'station_id': 'S116', 'value': 28.7}, {'station_id': 'S104', 'value': 27.6}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T10:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 29.8}, {'station_id': 'S117', 'value': 30.3}, {'station_id': 'S50', 'value': 29.5}, {'station_id': 'S107', 'value': 29.3}, {'station_id': 'S43', 'value': 29.6}, {'station_id': 'S44', 'value': 29.5}, {'station_id': 'S121', 'value': 29.7}, {'station_id': 'S111', 'value': 30.6}, {'station_id': 'S60', 'value': 29.8}, {'station_id': 'S115', 'value': 28.8}, {'station_id': 'S24', 'value': 29.2}, {'station_id': 'S116', 'value': 29.7}, {'station_id': 'S104', 'value': 29.3}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T11:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 31.6}, {'station_id': 'S117', 'value': 29.9}, {'station_id': 'S107', 'value': 29.8}, {'station_id': 'S43', 'value': 31.7}, {'station_id': 'S44', 'value': 30.5}, {'station_id': 'S121', 'value': 30.8}, {'station_id': 'S111', 'value': 31.3}, {'station_id': 'S60', 'value': 30.2}, {'station_id': 'S115', 'value': 30.6}, {'station_id': 'S24', 'value': 30.7}, {'station_id': 'S116', 'value': 29.6}, {'station_id': 'S104', 'value': 31.2}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T12:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 31.9}, {'station_id': 'S117', 'value': 30.7}, {'station_id': 'S107', 'value': 30}, {'station_id': 'S43', 'value': 31}, {'station_id': 'S44', 'value': 31.5}, {'station_id': 'S121', 'value': 32.1}, {'station_id': 'S111', 'value': 31.5}, {'station_id': 'S60', 'value': 31.5}, {'station_id': 'S115', 'value': 30.8}, {'station_id': 'S24', 'value': 31.2}, {'station_id': 'S116', 'value': 30.6}, {'station_id': 'S104', 'value': 32.1}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T13:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 32.2}, {'station_id': 'S117', 'value': 31.9}, {'station_id': 'S107', 'value': 30.4}, {'station_id': 'S43', 'value': 32.9}, {'station_id': 'S44', 'value': 31.3}, {'station_id': 'S121', 'value': 33.2}, {'station_id': 'S111', 'value': 34}, {'station_id': 'S60', 'value': 31.1}, {'station_id': 'S115', 'value': 31.4}, {'station_id': 'S24', 'value': 32.1}, {'station_id': 'S116', 'value': 31.1}, {'station_id': 'S104', 'value': 33}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T14:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 32.3}, {'station_id': 'S117', 'value': 31.8}, {'station_id': 'S107', 'value': 30.6}, {'station_id': 'S43', 'value': 32.8}, {'station_id': 'S44', 'value': 31.1}, {'station_id': 'S121', 'value': 33.3}, {'station_id': 'S111', 'value': 32.7}, {'station_id': 'S60', 'value': 31.4}, {'station_id': 'S115', 'value': 31.1}, {'station_id': 'S24', 'value': 31.8}, {'station_id': 'S116', 'value': 31}, {'station_id': 'S104', 'value': 34}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T15:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 32}, {'station_id': 'S117', 'value': 31.8}, {'station_id': 'S107', 'value': 30.7}, {'station_id': 'S43', 'value': 32.7}, {'station_id': 'S44', 'value': 31.9}, {'station_id': 'S121', 'value': 32.8}, {'station_id': 'S111', 'value': 30.7}, {'station_id': 'S60', 'value': 32.4}, {'station_id': 'S115', 'value': 31.6}, {'station_id': 'S24', 'value': 32.7}, {'station_id': 'S116', 'value': 31.1}, {'station_id': 'S104', 'value': 30.6}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T16:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 31.7}, {'station_id': 'S117', 'value': 31.8}, {'station_id': 'S50', 'value': 31.6}, {'station_id': 'S107', 'value': 29.9}, {'station_id': 'S43', 'value': 31.4}, {'station_id': 'S44', 'value': 32.3}, {'station_id': 'S121', 'value': 32.6}, {'station_id': 'S111', 'value': 31.4}, {'station_id': 'S60', 'value': 30.8}, {'station_id': 'S115', 'value': 32.1}, {'station_id': 'S24', 'value': 29.1}, {'station_id': 'S116', 'value': 31.5}, {'station_id': 'S104', 'value': 32.8}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T17:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 29.5}, {'station_id': 'S117', 'value': 30.2}, {'station_id': 'S50', 'value': 30.2}, {'station_id': 'S107', 'value': 28.8}, {'station_id': 'S43', 'value': 29.4}, {'station_id': 'S44', 'value': 30.7}, {'station_id': 'S121', 'value': 30.9}, {'station_id': 'S111', 'value': 28.7}, {'station_id': 'S60', 'value': 29}, {'station_id': 'S115', 'value': 30.4}, {'station_id': 'S24', 'value': 29}, {'station_id': 'S116', 'value': 30.8}, {'station_id': 'S104', 'value': 30.9}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T18:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 28.1}, {'station_id': 'S117', 'value': 29.5}, {'station_id': 'S50', 'value': 29.1}, {'station_id': 'S107', 'value': 28.9}, {'station_id': 'S43', 'value': 28.9}, {'station_id': 'S44', 'value': 27.4}, {'station_id': 'S121', 'value': 29.5}, {'station_id': 'S111', 'value': 28}, {'station_id': 'S60', 'value': 28.4}, {'station_id': 'S115', 'value': 29.2}, {'station_id': 'S24', 'value': 28.7}, {'station_id': 'S116', 'value': 29.6}, {'station_id': 'S104', 'value': 27.8}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T19:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 28.5}, {'station_id': 'S117', 'value': 28.6}, {'station_id': 'S50', 'value': 28.6}, {'station_id': 'S107', 'value': 29.1}, {'station_id': 'S43', 'value': 28.7}, {'station_id': 'S44', 'value': 26.7}, {'station_id': 'S121', 'value': 28.8}, {'station_id': 'S111', 'value': 27.8}, {'station_id': 'S60', 'value': 28.3}, {'station_id': 'S115', 'value': 29.1}, {'station_id': 'S24', 'value': 28.4}, {'station_id': 'S116', 'value': 28.5}, {'station_id': 'S104', 'value': 28.4}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-01T20:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 28.6}, {'station_id': 'S117', 'value': 28.5}, {'station_id': 'S50', 'value': 28.5}, {'station_id': 'S107', 'value': 29.2}, {'station_id': 'S43', 'value': 28.8}, {'station_id': 'S44', 'value': 27.5}, {'station_id': 'S121', 'value': 28.7}, {'station_id': 'S111', 'value': 27.9}, {'station_id': 'S60', 'value': 28.2}, {'station_id': 'S115', 'value': 28.9}, {'station_id': 'S24', 'value': 28.7}, {'station_id': 'S116', 'value': 29.1}, {'station_id': 'S104', 'value': 28.5}]}], 'api_info': {'status': 'healthy'}}
# ...
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-17T12:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 32}, {'station_id': 'S117', 'value': 30.5}, {'station_id': 'S50', 'value': 31.2}, {'station_id': 'S107', 'value': 30.9}, {'station_id': 'S43', 'value': 32.9}, {'station_id': 'S44', 'value': 32.4}, {'station_id': 'S121', 'value': 32.9}, {'station_id': 'S111', 'value': 32.9}, {'station_id': 'S60', 'value': 31.9}, {'station_id': 'S115', 'value': 31.7}, {'station_id': 'S24', 'value': 32.3}, {'station_id': 'S116', 'value': 30.9}, {'station_id': 'S104', 'value': 32.1}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-17T13:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 32.8}, {'station_id': 'S117', 'value': 32.9}, {'station_id': 'S50', 'value': 31.9}, {'station_id': 'S107', 'value': 30.9}, {'station_id': 'S43', 'value': 32.8}, {'station_id': 'S44', 'value': 32.3}, {'station_id': 'S121', 'value': 33.5}, {'station_id': 'S111', 'value': 32.3}, {'station_id': 'S60', 'value': 32.2}, {'station_id': 'S115', 'value': 32.4}, {'station_id': 'S24', 'value': 32.3}, {'station_id': 'S116', 'value': 30.8}, {'station_id': 'S104', 'value': 33.6}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-17T14:00:00+08:00', 'readings': [{'station_id': 'S107', 'value': 31.4}, {'station_id': 'S121', 'value': 33.6}, {'station_id': 'S24', 'value': 33.2}, {'station_id': 'S104', 'value': 34.2}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-17T14:00:00+08:00', 'readings': [{'station_id': 'S107', 'value': 31.4}, {'station_id': 'S121', 'value': 33.6}, {'station_id': 'S24', 'value': 33.2}, {'station_id': 'S104', 'value': 34.2}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-17T14:00:00+08:00', 'readings': [{'station_id': 'S107', 'value': 31.4}, {'station_id': 'S121', 'value': 33.6}, {'station_id': 'S24', 'value': 33.2}, {'station_id': 'S104', 'value': 34.2}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-17T17:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 32.7}, {'station_id': 'S117', 'value': 31.7}, {'station_id': 'S50', 'value': 31.7}, {'station_id': 'S107', 'value': 31.9}, {'station_id': 'S43', 'value': 32.5}, {'station_id': 'S44', 'value': 32}, {'station_id': 'S121', 'value': 32.5}, {'station_id': 'S111', 'value': 32.2}, {'station_id': 'S60', 'value': 32.4}, {'station_id': 'S115', 'value': 31.8}, {'station_id': 'S24', 'value': 32.8}, {'station_id': 'S116', 'value': 32.2}, {'station_id': 'S104', 'value': 32.8}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-17T18:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 32.3}, {'station_id': 'S117', 'value': 31.6}, {'station_id': 'S50', 'value': 31.1}, {'station_id': 'S107', 'value': 31.5}, {'station_id': 'S43', 'value': 32.2}, {'station_id': 'S44', 'value': 31.5}, {'station_id': 'S121', 'value': 31.8}, {'station_id': 'S111', 'value': 31.3}, {'station_id': 'S60', 'value': 31.5}, {'station_id': 'S115', 'value': 31.6}, {'station_id': 'S24', 'value': 31.7}, {'station_id': 'S116', 'value': 31.7}, {'station_id': 'S104', 'value': 32}]}], 'api_info': {'status': 'healthy'}}
# {'metadata': {'stations': [{'id': 'S109', 'device_id': 'S109', 'name': 'Ang Mo Kio Avenue 5', 'location': {'latitude': 1.3764, 'longitude': 103.8492}}, {'id': 'S117', 'device_id': 'S117', 'name': 'Banyan Road', 'location': {'latitude': 1.256, 'longitude': 103.679}}, {'id': 'S50', 'device_id': 'S50', 'name': 'Clementi Road', 'location': {'latitude': 1.3337, 'longitude': 103.7768}}, {'id': 'S107', 'device_id': 'S107', 'name': 'East Coast Parkway', 'location': {'latitude': 1.3135, 'longitude': 103.9625}}, {'id': 'S43', 'device_id': 'S43', 'name': 'Kim Chuan Road', 'location': {'latitude': 1.3399, 'longitude': 103.8878}}, {'id': 'S44', 'device_id': 'S44', 'name': 'Nanyang Avenue', 'location': {'latitude': 1.34583, 'longitude': 103.68166}}, {'id': 'S121', 'device_id': 'S121', 'name': 'Old Choa Chu Kang Road', 'location': {'latitude': 1.37288, 'longitude': 103.72244}}, {'id': 'S111', 'device_id': 'S111', 'name': 'Scotts Road', 'location': {'latitude': 1.31055, 'longitude': 103.8365}}, {'id': 'S60', 'device_id': 'S60', 'name': 'Sentosa', 'location': {'latitude': 1.25, 'longitude': 103.8279}}, {'id': 'S115', 'device_id': 'S115', 'name': 'Tuas South Avenue 3', 'location': {'latitude': 1.29377, 'longitude': 103.61843}}, {'id': 'S24', 'device_id': 'S24', 'name': 'Upper Changi Road North', 'location': {'latitude': 1.3678, 'longitude': 103.9826}}, {'id': 'S116', 'device_id': 'S116', 'name': 'West Coast Highway', 'location': {'latitude': 1.281, 'longitude': 103.754}}, {'id': 'S104', 'device_id': 'S104', 'name': 'Woodlands Avenue 9', 'location': {'latitude': 1.44387, 'longitude': 103.78538}}], 'reading_type': 'DBT 1M F', 'reading_unit': 'deg C'}, 'items': [{'timestamp': '2023-10-17T19:00:00+08:00', 'readings': [{'station_id': 'S109', 'value': 31.6}, {'station_id': 'S117', 'value': 30.5}, {'station_id': 'S50', 'value': 30.6}, {'station_id': 'S107', 'value': 31}, {'station_id': 'S43', 'value': 31.2}, {'station_id': 'S44', 'value': 30.6}, {'station_id': 'S121', 'value': 30.9}, {'station_id': 'S111', 'value': 30.3}, {'station_id': 'S60', 'value': 30.2}, {'station_id': 'S115', 'value': 30.9}, {'station_id': 'S24', 'value': 30.7}, {'station_id': 'S116', 'value': 31.1}, {'station_id': 'S104', 'value': 30.9}]}], 'api_info': {'status': 'healthy'}}
